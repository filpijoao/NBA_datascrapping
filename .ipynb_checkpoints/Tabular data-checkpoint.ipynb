# %% [markdown]
# ### Imports básicos

# %%
import requests
from bs4 import BeautifulSoup
import math
import random

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime
import time

# %%
today = datetime.today().strftime('%Y-%m-%d')

# %%
year = today[0:4]
month = today[5:7]
day = int(today[8:10]) -1

# %%
print(year)
print(month)
print(day)
# Out:
# 2024
# 11
# 0

# %% [markdown]
# # Explorando os dados

# %% [markdown]
# ## Funções para o Download das informações

# %%
#Função para armazenar os jogos do dia
def get_games(d, m, y, url_list):
    
    #adicionando um timer para não sobrecarregar o site
    time.sleep(random.randint(8, 12))
    
    #Definindo a url do dia
    url = f"https://www.basketball-reference.com/boxscores/?month={m}&day={d}&year={y}"
    
    #Download do site
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    #Lista de jogos do dia
    games = soup.find('div', id='content').find('div', class_='game_summaries'
                        ).find_all('div', class_='game_summary expanded nohover')
    
    #Adicionando Urls do play_by_play
    for i in games:
        url_list.append(i.find('p', class_='links').find_all('a')[1].attrs['href'])

# %%
#Função para coletar os dados de cada jogo para a tabelas de jogos
def get_game_infos(d, m, y, games_dict, url):
    
    #adicionando um timer para não sobrecarregar o site
    time.sleep(random.randint(8, 12))
    
    #Fazendo Download do site
    pbp_url = f'https://www.basketball-reference.com{url}'
    response_pbp = requests.get(pbp_url)
    soup_pbp = BeautifulSoup(response_pbp.content, "html.parser")
    
    #Getting dict keys
    dict_keys = list(games_dict)
    
    #Adicionando chave e infos do dias
    games_dict[dict_keys[0]].append(url)
    games_dict[dict_keys[1]].append(d)
    games_dict[dict_keys[2]].append(m)
    games_dict[dict_keys[3]].append(y)    
    
    #Adicionando infos do away team
    away_team_name = soup_pbp.find('div', class_="scorebox").find_all('div')[0].find('strong').find('a').text
    games_dict[dict_keys[4]].append(away_team_name)
    away_team_score = soup_pbp.find('div', class_="scorebox").find_all('div')[0].find('div', class_ = 'score').text
    games_dict[dict_keys[5]].append(away_team_score)
    away_team_key = soup_pbp.find('div', class_="scorebox").find_all('div')[0].find('strong').find('a').attrs['href']
    games_dict[dict_keys[6]].append(away_team_key)
    
    #Adicionando infos do home team
    home_team_name = soup_pbp.find('div', class_="scorebox").find_all('div')[7].find('strong').find('a').text
    games_dict[dict_keys[8]].append(home_team_name)
    home_team_score = soup_pbp.find('div', class_="scorebox").find_all('div')[7].find('div', class_ = 'score').text
    games_dict[dict_keys[9]].append(home_team_score)
    home_team_key = soup_pbp.find('div', class_="scorebox").find_all('div')[7].find('strong').find('a').attrs['href']
    games_dict[dict_keys[10]].append(home_team_key)
    
    #Calculando o Ganhador
    if int(away_team_score) > int(home_team_score):
        games_dict[dict_keys[7]].append('W')
        games_dict[dict_keys[11]].append('L')
    else:
        games_dict[dict_keys[11]].append('W')
        games_dict[dict_keys[7]].append('L')    
        
    #Coletando o play by play
    plays = soup_pbp.find('table').find_all('tr')   
    pbp = get_pbp(plays, url, away_team_name, home_team_name)
    games_dict[dict_keys[12]].append(pbp)

# %%
# Função para coletar o play by play
def get_pbp(pbp_table, key, at, ht):

    #Dicionários com as info básicas de cada jogo
    dict_pbp = {
    'key' : [],
    'quarter' : [],
    'time' : [],
    'score' : [],
    'team_play' : [],
    'play': [],
    }
    
    #Apoio para calcular o quarto
    q = 1
    
    #Loop para fazer o download das jogadas
    for i in pbp_table[3:]:
    
        #Checar primeiro se uma linha da tabela com jogadas
        if len(i.find_all('td')) == 6:
            dict_pbp['key'].append(key)
            dict_pbp['quarter'].append(f"Q{q}")
            dict_pbp['time'].append(i.find_all('td')[0].text)
            dict_pbp['score'].append(i.find_all('td')[3].text)
          
            #Checando se a jogada foi do time visitante ou do time da casa
            if len(i.find_all('td')[1].text) > 2:
                dict_pbp['team_play'].append(at)
                dict_pbp['play'].append(i.find_all('td')[1].text)            
            
            elif len(i.find_all('td')[5].text) > 2:
                dict_pbp['team_play'].append(ht)
                dict_pbp['play'].append(i.find_all('td')[5].text)   
            
        #Bucando as linhas da tabela que indicam a mudança de quarto
        elif len(i.find_all('th')) == 1:
            q += 1
    
    return dict_pbp

# %%
games_table = {
    'key' : [],
    'day' : [],
    'month' : [],
    'year' : [],
    'away_team' : [],
    'away_team_score' : [],
    'away_team_key' : [],
    'away_team_W/L': [],
    'home_team' : [],
    'home_team_score' : [],
    'home_team_key' : [],
    'home_team_W/L': [],
    'game_pbp' : []
}

# %% [markdown]
# ## Checando as DFs para ver se o downaload foi eficaz

# %% [markdown]
# ### Coletando os dados

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='30', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='30', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410300CHI.html
# /boxscores/pbp/202410300CHO.html
# /boxscores/pbp/202410300CLE.html
# /boxscores/pbp/202410300GSW.html
# /boxscores/pbp/202410300IND.html
# /boxscores/pbp/202410300LAC.html
# /boxscores/pbp/202410300MEM.html
# /boxscores/pbp/202410300MIA.html
# /boxscores/pbp/202410300OKC.html
# /boxscores/pbp/202410300PHI.html
# /boxscores/pbp/202410300WAS.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='29', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='29', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410290BRK.html
# /boxscores/pbp/202410290GSW.html
# /boxscores/pbp/202410290MIN.html
# /boxscores/pbp/202410290UTA.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='28', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='28', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410280ATL.html
# /boxscores/pbp/202410280BOS.html
# /boxscores/pbp/202410280DAL.html
# /boxscores/pbp/202410280MEM.html
# /boxscores/pbp/202410280MIA.html
# /boxscores/pbp/202410280NYK.html
# /boxscores/pbp/202410280ORL.html
# /boxscores/pbp/202410280PHO.html
# /boxscores/pbp/202410280SAC.html
# /boxscores/pbp/202410280SAS.html
# /boxscores/pbp/202410280TOR.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='27', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='27', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410270BRK.html
# /boxscores/pbp/202410270GSW.html
# /boxscores/pbp/202410270IND.html
# /boxscores/pbp/202410270OKC.html
# /boxscores/pbp/202410270POR.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='26', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='26', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410260CHI.html
# /boxscores/pbp/202410260CHO.html
# /boxscores/pbp/202410260DEN.html
# /boxscores/pbp/202410260DET.html
# /boxscores/pbp/202410260LAL.html
# /boxscores/pbp/202410260MEM.html
# /boxscores/pbp/202410260MIN.html
# /boxscores/pbp/202410260PHO.html
# /boxscores/pbp/202410260SAS.html
# /boxscores/pbp/202410260WAS.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='25', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='25', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410250ATL.html
# /boxscores/pbp/202410250CLE.html
# /boxscores/pbp/202410250HOU.html
# /boxscores/pbp/202410250LAL.html
# /boxscores/pbp/202410250MIL.html
# /boxscores/pbp/202410250NYK.html
# /boxscores/pbp/202410250ORL.html
# /boxscores/pbp/202410250POR.html
# /boxscores/pbp/202410250TOR.html
# /boxscores/pbp/202410250UTA.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='24', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='24', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410240DAL.html
# /boxscores/pbp/202410240DEN.html
# /boxscores/pbp/202410240SAC.html
# /boxscores/pbp/202410240WAS.html

# %%
#Usando um dia travado para não comprometer as análises futuras
today_urls = []
get_games(d='23', m='10', y='2024', url_list=today_urls)

# %%
for i in today_urls:
    get_game_infos(d='23', m='10', y='2024', games_dict=games_table, url=i)
    print(i)
# Out:
# /boxscores/pbp/202410230ATL.html
# /boxscores/pbp/202410230DET.html
# /boxscores/pbp/202410230HOU.html
# /boxscores/pbp/202410230LAC.html
# /boxscores/pbp/202410230MIA.html
# /boxscores/pbp/202410230NOP.html
# /boxscores/pbp/202410230PHI.html
# /boxscores/pbp/202410230POR.html
# /boxscores/pbp/202410230TOR.html
# /boxscores/pbp/202410230UTA.html

# %% [markdown]
# ### Checando estrutura da tabela de jogos

# %%
# Criando uma tabela apenas com so resultados dos jogos
table = games_table.copy()
table.pop('game_pbp')
games_df = pd.DataFrame(table)
games_df
# Out:
#                                  key day month  year              away_team  \
# 0   /boxscores/pbp/202410300CHI.html  30    10  2024          Orlando Magic
# 1   /boxscores/pbp/202410300CHO.html  30    10  2024        Toronto Raptors
# 2   /boxscores/pbp/202410300CLE.html  30    10  2024     Los Angeles Lakers
# 3   /boxscores/pbp/202410300GSW.html  30    10  2024   New Orleans Pelicans
# 4   /boxscores/pbp/202410300IND.html  30    10  2024         Boston Celtics
# ..                               ...  ..   ...   ...                    ...
# 60  /boxscores/pbp/202410230NOP.html  23    10  2024          Chicago Bulls
# 61  /boxscores/pbp/202410230PHI.html  23    10  2024        Milwaukee Bucks
# 62  /boxscores/pbp/202410230POR.html  23    10  2024  Golden State Warriors
# 63  /boxscores/pbp/202410230TOR.html  23    10  2024    Cleveland Cavaliers
# 64  /boxscores/pbp/202410230UTA.html  23    10  2024      Memphis Grizzlies
#
#    away_team_score         away_team_key away_team_W/L  \
# 0               99  /teams/ORL/2025.html             L
# 1              133  /teams/TOR/2025.html             L
# 2              110  /teams/LAL/2025.html             L
# 3               89  /teams/NOP/2025.html             L
# 4              132  /teams/BOS/2025.html             L
# ..             ...                   ...           ...
# 60             111  /teams/CHI/2025.html             L
# 61             124  /teams/MIL/2025.html             W
# 62             140  /teams/GSW/2025.html             W
# 63             136  /teams/CLE/2025.html             W
# 64             126  /teams/MEM/2025.html             W
#
#                  home_team home_team_score         home_team_key home_team_W/L
# 0            Chicago Bulls             102  /teams/CHI/2025.html             W
# 1        Charlotte Hornets             138  /teams/CHO/2025.html             W
# 2      Cleveland Cavaliers             134  /teams/CLE/2025.html             W
# 3    Golden State Warriors             104  /teams/GSW/2025.html             W
# 4           Indiana Pacers             135  /teams/IND/2025.html             W
# ..                     ...             ...                   ...           ...
# 60    New Orleans Pelicans             123  /teams/NOP/2025.html             W
# 61      Philadelphia 76ers             109  /teams/PHI/2025.html             L
# 62  Portland Trail Blazers             104  /teams/POR/2025.html             L
# 63         Toronto Raptors             106  /teams/TOR/2025.html             L
# 64               Utah Jazz             124  /teams/UTA/2025.html             L
#
# [65 rows x 12 columns]

# %% [markdown]
# Checando A estrutura do Play - by - Play

# %%
# Criando um dataframe 
pbp_df = pd.DataFrame(games_table['game_pbp'][0])
for i in games_table['game_pbp'][1:]:
    temp_df = pd.DataFrame(i)
    pbp_df = pd.concat([pbp_df, temp_df])

pbp_df
# Out:
#                                   key quarter     time    score  \
# 0    /boxscores/pbp/202410300CHI.html      Q1  11:44.0      3-0
# 1    /boxscores/pbp/202410300CHI.html      Q1  11:27.0      3-2
# 2    /boxscores/pbp/202410300CHI.html      Q1  11:15.0      3-2
# 3    /boxscores/pbp/202410300CHI.html      Q1  11:12.0      3-2
# 4    /boxscores/pbp/202410300CHI.html      Q1  11:01.0      3-2
# ..                                ...     ...      ...      ...
# 531  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  125-121
# 532  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 533  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 534  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 535  /boxscores/pbp/202410230UTA.html      Q4   0:04.0  126-124
#
#              team_play                                               play
# 0        Orlando Magic  K. Caldwell-Pope makes 3-pt jump shot from 26 ...
# 1        Chicago Bulls          J. Giddey makes 2-pt jump shot from 20 ft
# 2        Orlando Magic        P. Banchero misses 2-pt jump shot from 6 ft
# 3        Chicago Bulls                     Defensive rebound by J. Giddey
# 4        Chicago Bulls            P. Williams misses 2-pt layup from 2 ft
# ..                 ...                                                ...
# 531  Memphis Grizzlies                    D. Bane makes free throw 1 of 2
# 532  Memphis Grizzlies                    D. Bane makes free throw 2 of 2
# 533          Utah Jazz                                  Utah full timeout
# 534          Utah Jazz           C. Sexton enters the game for W. Kessler
# 535          Utah Jazz  L. Markkanen makes 3-pt jump shot from 27 ft (...
#
# [31157 rows x 6 columns]

# %% [markdown]
# Misturando as duas dfs

# %%
merge_df = pbp_df.merge(games_df[['key', 'away_team', 'home_team']], on='key')
merge_df
# Out:
#                                     key quarter     time    score  \
# 0      /boxscores/pbp/202410300CHI.html      Q1  11:44.0      3-0
# 1      /boxscores/pbp/202410300CHI.html      Q1  11:27.0      3-2
# 2      /boxscores/pbp/202410300CHI.html      Q1  11:15.0      3-2
# 3      /boxscores/pbp/202410300CHI.html      Q1  11:12.0      3-2
# 4      /boxscores/pbp/202410300CHI.html      Q1  11:01.0      3-2
# ...                                 ...     ...      ...      ...
# 31152  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  125-121
# 31153  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31154  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31155  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31156  /boxscores/pbp/202410230UTA.html      Q4   0:04.0  126-124
#
#                team_play                                               play  \
# 0          Orlando Magic  K. Caldwell-Pope makes 3-pt jump shot from 26 ...
# 1          Chicago Bulls          J. Giddey makes 2-pt jump shot from 20 ft
# 2          Orlando Magic        P. Banchero misses 2-pt jump shot from 6 ft
# 3          Chicago Bulls                     Defensive rebound by J. Giddey
# 4          Chicago Bulls            P. Williams misses 2-pt layup from 2 ft
# ...                  ...                                                ...
# 31152  Memphis Grizzlies                    D. Bane makes free throw 1 of 2
# 31153  Memphis Grizzlies                    D. Bane makes free throw 2 of 2
# 31154          Utah Jazz                                  Utah full timeout
# 31155          Utah Jazz           C. Sexton enters the game for W. Kessler
# 31156          Utah Jazz  L. Markkanen makes 3-pt jump shot from 27 ft (...
#
#                away_team      home_team
# 0          Orlando Magic  Chicago Bulls
# 1          Orlando Magic  Chicago Bulls
# 2          Orlando Magic  Chicago Bulls
# 3          Orlando Magic  Chicago Bulls
# 4          Orlando Magic  Chicago Bulls
# ...                  ...            ...
# 31152  Memphis Grizzlies      Utah Jazz
# 31153  Memphis Grizzlies      Utah Jazz
# 31154  Memphis Grizzlies      Utah Jazz
# 31155  Memphis Grizzlies      Utah Jazz
# 31156  Memphis Grizzlies      Utah Jazz
#
# [31157 rows x 8 columns]

# %% [markdown]
# Função para Pré Processar os dados

# %%
# Função para limpar os nomes
from nltk.tokenize import word_tokenize

def processing_text(text):
    
    text = text.replace('(', '').replace(')', '').replace(".",'').replace(".."
                    , '').replace(";", '').lower().replace('da silva', 'dasilva')
    
    text = word_tokenize(text)
    
    return text

# %%
merge_df['clean_play'] = merge_df['play'].apply(processing_text)
merge_df
# Out:
#                                     key quarter     time    score  \
# 0      /boxscores/pbp/202410300CHI.html      Q1  11:44.0      3-0
# 1      /boxscores/pbp/202410300CHI.html      Q1  11:27.0      3-2
# 2      /boxscores/pbp/202410300CHI.html      Q1  11:15.0      3-2
# 3      /boxscores/pbp/202410300CHI.html      Q1  11:12.0      3-2
# 4      /boxscores/pbp/202410300CHI.html      Q1  11:01.0      3-2
# ...                                 ...     ...      ...      ...
# 31152  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  125-121
# 31153  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31154  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31155  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31156  /boxscores/pbp/202410230UTA.html      Q4   0:04.0  126-124
#
#                team_play                                               play  \
# 0          Orlando Magic  K. Caldwell-Pope makes 3-pt jump shot from 26 ...
# 1          Chicago Bulls          J. Giddey makes 2-pt jump shot from 20 ft
# 2          Orlando Magic        P. Banchero misses 2-pt jump shot from 6 ft
# 3          Chicago Bulls                     Defensive rebound by J. Giddey
# 4          Chicago Bulls            P. Williams misses 2-pt layup from 2 ft
# ...                  ...                                                ...
# 31152  Memphis Grizzlies                    D. Bane makes free throw 1 of 2
# 31153  Memphis Grizzlies                    D. Bane makes free throw 2 of 2
# 31154          Utah Jazz                                  Utah full timeout
# 31155          Utah Jazz           C. Sexton enters the game for W. Kessler
# 31156          Utah Jazz  L. Markkanen makes 3-pt jump shot from 27 ft (...
#
#                away_team      home_team  \
# 0          Orlando Magic  Chicago Bulls
# 1          Orlando Magic  Chicago Bulls
# 2          Orlando Magic  Chicago Bulls
# 3          Orlando Magic  Chicago Bulls
# 4          Orlando Magic  Chicago Bulls
# ...                  ...            ...
# 31152  Memphis Grizzlies      Utah Jazz
# 31153  Memphis Grizzlies      Utah Jazz
# 31154  Memphis Grizzlies      Utah Jazz
# 31155  Memphis Grizzlies      Utah Jazz
# 31156  Memphis Grizzlies      Utah Jazz
#
#                                               clean_play
# 0      [k, caldwell-pope, makes, 3-pt, jump, shot, fr...
# 1      [j, giddey, makes, 2-pt, jump, shot, from, 20,...
# 2      [p, banchero, misses, 2-pt, jump, shot, from, ...
# 3                    [defensive, rebound, by, j, giddey]
# 4        [p, williams, misses, 2-pt, layup, from, 2, ft]
# ...                                                  ...
# 31152            [d, bane, makes, free, throw, 1, of, 2]
# 31153            [d, bane, makes, free, throw, 2, of, 2]
# 31154                              [utah, full, timeout]
# 31155    [c, sexton, enters, the, game, for, w, kessler]
# 31156  [l, markkanen, makes, 3-pt, jump, shot, from, ...
#
# [31157 rows x 9 columns]

# %% [markdown]
# # Explorando os tipos de jogadas para criar as colunas da nossa base de dados

# %% [markdown]
# ### Criando lista com todas as jogadas do dia para a exploração e funções para tratar os dados

# %%
#Criando uma lista com todas as jogadas do dia
plays_list = []
import string

for i in games_table['game_pbp']:
    for x in i['play']:
        plays_list.append(x)

plays_list = [x.replace('(', '').replace(')', '').replace(".",
            '').replace("..", '').replace(";", '').lower() for x in plays_list]

plays_list
# Out:
# ['k caldwell-pope makes 3-pt jump shot from 26 ft assist by p banchero',
#  'j giddey makes 2-pt jump shot from 20 ft',
#  'p banchero misses 2-pt jump shot from 6 ft',
#  'defensive rebound by j giddey',
#  'p williams misses 2-pt layup from 2 ft',
#  'offensive rebound by n vučević',
#  'p williams misses 3-pt jump shot from 26 ft',
#  'defensive rebound by p banchero',
#  'p banchero makes 2-pt jump shot from 22 ft assist by w carter',
#  'c white misses 3-pt jump shot from 25 ft',
#  'defensive rebound by p banchero',
#  'f wagner makes 2-pt layup from 1 ft assist by p banchero',
#  'n vučević misses 2-pt layup from 2 ft',
#  'defensive rebound by p banchero',
#  'p banchero makes 2-pt layup at rim',
#  'j giddey misses 2-pt jump shot from 2 ft',
#  'defensive rebound by j suggs',
#  'j suggs misses 3-pt jump shot from 29 ft',
#  'defensive rebound by p williams',
#  'chicago full timeout',
#  'z lavine misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j suggs',
#  'w carter misses 3-pt jump shot from 25 ft',
#  'defensive rebound by n vučević',
#  'j giddey misses 2-pt hook shot from 4 ft block by f wagner',
#  'offensive rebound by j giddey',
#  'c white makes 2-pt jump shot from 13 ft',
#  'k caldwell-pope misses 3-pt jump shot from 24 ft',
#  'defensive rebound by n vučević',
#  'shooting foul by j suggs drawn by p williams',
#  'p williams makes free throw 1 of 2',
#  'p williams misses free throw 2 of 2',
#  'defensive rebound by w carter',
#  'turnover by j suggs bad pass steal by z lavine',
#  'shooting foul by p banchero drawn by z lavine',
#  'z lavine makes free throw 1 of 2',
#  'z lavine makes free throw 2 of 2',
#  'w carter makes 2-pt jump shot from 14 ft assist by p banchero',
#  'z lavine misses 2-pt layup from 3 ft',
#  'defensive rebound by j suggs',
#  'j suggs makes 3-pt jump shot from 25 ft assist by f wagner',
#  'j giddey makes 2-pt layup from 1 ft',
#  'k caldwell-pope misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j giddey',
#  'p williams misses 2-pt layup from 4 ft block by j suggs',
#  'defensive rebound by j suggs',
#  'p banchero makes 3-pt jump shot from 26 ft',
#  'n vučević misses 2-pt hook shot from 10 ft block by j suggs',
#  'defensive rebound by f wagner',
#  'j suggs makes 3-pt jump shot from 25 ft assist by k caldwell-pope',
#  'personal foul by f wagner drawn by z lavine',
#  'g harris enters the game for f wagner',
#  'a dosunmu enters the game for c white',
#  'j phillips enters the game for p williams',
#  'turnover by z lavine lost ball steal by j suggs',
#  'w carter makes 2-pt dunk from 1 ft assist by j suggs',
#  'j giddey misses 2-pt jump shot from 6 ft',
#  'defensive rebound by p banchero',
#  'shooting foul by j giddey drawn by p banchero',
#  'p banchero makes free throw 1 of 2',
#  'p banchero makes free throw 2 of 2',
#  'turnover by z lavine bad pass steal by k caldwell-pope',
#  'turnover by j suggs bad pass steal by j phillips',
#  'turnover by z lavine bad pass steal by j suggs',
#  'w carter makes 2-pt dunk from 1 ft assist by j suggs',
#  'j phillips makes 3-pt jump shot from 24 ft assist by j giddey',
#  'p banchero makes 2-pt layup from 1 ft',
#  'a dosunmu makes 2-pt layup from 1 ft assist by j giddey',
#  'j suggs makes 2-pt layup from 1 ft',
#  'chicago full timeout',
#  'a black enters the game for p banchero',
#  'j isaac enters the game for k caldwell-pope',
#  'm wagner enters the game for w carter',
#  'd terry enters the game for j giddey',
#  'c white enters the game for z lavine',
#  'turnover by j phillips traveling',
#  'j suggs makes 3-pt jump shot from 26 ft assist by a black',
#  'd terry misses 3-pt jump shot from 25 ft',
#  'defensive rebound by m wagner',
#  'g harris misses 3-pt jump shot from 25 ft',
#  'defensive rebound by d terry',
#  'j phillips misses 3-pt jump shot from 26 ft',
#  'defensive rebound by m wagner',
#  'a black misses 2-pt layup from 1 ft block by a dosunmu',
#  'defensive rebound by j phillips',
#  'c white misses 2-pt jump shot from 23 ft',
#  'offensive rebound by n vučević',
#  'n vučević makes 2-pt jump shot from 8 ft',
#  'j suggs misses 3-pt jump shot from 27 ft',
#  'defensive rebound by n vučević',
#  'n vučević misses 3-pt jump shot from 25 ft',
#  'defensive rebound by m wagner',
#  'm wagner misses 3-pt jump shot from 25 ft',
#  'defensive rebound by a dosunmu',
#  'violation by team kicked ball',
#  'j howard enters the game for j suggs',
#  'c white makes 2-pt layup from 2 ft assist by n vučević',
#  'a black misses 3-pt jump shot from 26 ft',
#  'offensive rebound by j isaac',
#  'turnover by j isaac lost ball steal by c white',
#  'c white misses 3-pt jump shot from 71 ft',
#  'offensive rebound by team',
#  'c white makes 2-pt jump shot from 10 ft',
#  'shooting foul by a sanogo drawn by m wagner',
#  'm wagner makes free throw 1 of 2',
#  'm wagner makes free throw 2 of 2',
#  'c white misses 3-pt jump shot from 26 ft',
#  'defensive rebound by j howard',
#  'j howard misses 3-pt jump shot from 25 ft',
#  'offensive rebound by j isaac',
#  'shooting foul by d terry drawn by j isaac',
#  'j isaac makes free throw 1 of 2',
#  'm buzelis enters the game for j phillips',
#  'j giddey enters the game for d terry',
#  'j isaac makes free throw 2 of 2',
#  'j giddey makes 3-pt jump shot from 23 ft assist by c white',
#  'j isaac makes 3-pt jump shot from 23 ft assist by a black',
#  'a dosunmu makes 2-pt jump shot from 4 ft',
#  'm wagner makes 3-pt jump shot from 26 ft assist by f wagner',
#  'a sanogo makes 2-pt layup from 1 ft assist by a dosunmu',
#  'f wagner makes 2-pt layup from 1 ft assist by a black',
#  'shooting foul by j howard drawn by c white',
#  'c white misses free throw 1 of 2',
#  'offensive rebound by team',
#  'p banchero enters the game for j isaac',
#  'z lavine enters the game for a dosunmu',
#  'c white makes free throw 2 of 2',
#  'j howard makes 3-pt jump shot from 23 ft assist by a black',
#  'c white makes 3-pt jump shot from 27 ft',
#  'p banchero makes 2-pt jump shot from 1 ft assist by f wagner',
#  'm buzelis misses 2-pt jump shot from 11 ft block by j howard',
#  'defensive rebound by m wagner',
#  'f wagner misses 3-pt jump shot from 25 ft',
#  'defensive rebound by z lavine',
#  'c white makes 3-pt jump shot from 26 ft assist by z lavine',
#  'j howard misses 3-pt jump shot from 24 ft',
#  'defensive rebound by z lavine',
#  'personal foul by f wagner drawn by a sanogo',
#  'w carter enters the game for m wagner',
#  'd terry enters the game for a sanogo',
#  'n vučević enters the game for c white',
#  'd terry misses 2-pt layup from 1 ft',
#  'offensive rebound by n vučević',
#  'n vučević misses 2-pt layup at rim',
#  'offensive rebound by n vučević',
#  'personal foul by w carter drawn by n vučević',
#  'z lavine misses 2-pt layup from 2 ft block by w carter',
#  'offensive rebound by team',
#  'chicago full timeout',
#  'n vučević misses 2-pt hook shot from 10 ft',
#  'defensive rebound by w carter',
#  'p banchero makes 2-pt layup from 1 ft',
#  'shooting foul by j giddey drawn by p banchero',
#  'k caldwell-pope enters the game for j howard',
#  'a dosunmu enters the game for m buzelis',
#  'p williams enters the game for d terry',
#  'p banchero misses free throw 1 of 1',
#  'defensive rebound by n vučević',
#  'n vučević makes 2-pt jump shot from 4 ft assist by p williams',
#  'k caldwell-pope misses 2-pt layup from 2 ft',
#  'defensive rebound by n vučević',
#  'shooting foul by w carter drawn by j giddey',
#  'j giddey makes free throw 1 of 2',
#  'j suggs enters the game for a black',
#  'j giddey makes free throw 2 of 2',
#  'w carter misses 2-pt jump shot from 18 ft',
#  'defensive rebound by a dosunmu',
#  'turnover by n vučević lost ball steal by f wagner',
#  'k caldwell-pope misses 3-pt jump shot from 24 ft',
#  'defensive rebound by p williams',
#  'a dosunmu makes 2-pt layup from 1 ft assist by p williams',
#  'p banchero misses 3-pt jump shot from 28 ft',
#  'offensive rebound by k caldwell-pope',
#  'p banchero misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j giddey',
#  'a dosunmu makes 2-pt layup from 1 ft assist by n vučević',
#  'shooting foul by k caldwell-pope drawn by a dosunmu',
#  'c white enters the game for j giddey',
#  'a dosunmu misses free throw 1 of 1',
#  'defensive rebound by w carter',
#  'f wagner makes 2-pt layup from 1 ft assist by p banchero',
#  'shooting foul by z lavine drawn by f wagner',
#  'f wagner makes free throw 1 of 1',
#  'a dosunmu makes 2-pt layup from 1 ft assist by n vučević',
#  'j suggs misses 3-pt jump shot from 25 ft',
#  'defensive rebound by a dosunmu',
#  'c white makes 2-pt layup from 1 ft',
#  'orlando full timeout',
#  'g harris enters the game for f wagner',
#  'w carter misses 3-pt jump shot from 26 ft',
#  'offensive rebound by g harris',
#  'p banchero makes 2-pt layup from 1 ft',
#  'z lavine misses 3-pt jump shot from 25 ft',
#  'defensive rebound by p banchero',
#  'shooting foul by z lavine drawn by p banchero',
#  'p banchero makes free throw 1 of 2',
#  'p banchero makes free throw 2 of 2',
#  'n vučević makes 2-pt jump shot from 13 ft assist by a dosunmu',
#  'j suggs misses 3-pt jump shot from 26 ft',
#  'defensive rebound by p williams',
#  'n vučević makes 2-pt layup from 1 ft',
#  'j suggs makes 2-pt jump shot from 17 ft',
#  'turnover by c white lost ball steal by j suggs',
#  'turnover by p banchero back court',
#  'z lavine makes 2-pt layup from 1 ft assist by c white',
#  'p banchero misses 3-pt jump shot from 26 ft',
#  'defensive rebound by c white',
#  'z lavine misses 3-pt jump shot from 25 ft',
#  'defensive rebound by team',
#  'd terry enters the game for z lavine',
#  'personal foul by a dosunmu drawn by p banchero',
#  'p banchero misses free throw 1 of 2',
#  'offensive rebound by team',
#  'j isaac enters the game for w carter',
#  'z lavine enters the game for d terry',
#  'p banchero makes free throw 2 of 2',
#  'p williams misses 3-pt jump shot from 25 ft',
#  'offensive rebound by n vučević',
#  'turnover by n vučević bad pass steal by j suggs',
#  'p banchero makes 2-pt layup from 1 ft assist by j suggs',
#  'c white misses 2-pt jump shot from 8 ft',
#  'offensive rebound by n vučević',
#  'n vučević misses 2-pt hook shot from 3 ft',
#  'defensive rebound by f wagner',
#  'f wagner misses 3-pt jump shot from 26 ft',
#  'defensive rebound by z lavine',
#  'shooting foul by j suggs drawn by n vučević',
#  'n vučević makes free throw 1 of 2',
#  'n vučević makes free throw 2 of 2',
#  'w carter misses 3-pt jump shot from 26 ft',
#  'defensive rebound by z lavine',
#  'c white misses 3-pt jump shot from 25 ft',
#  'defensive rebound by w carter',
#  'j suggs misses 3-pt jump shot from 26 ft',
#  'defensive rebound by z lavine',
#  'z lavine makes 3-pt jump shot from 27 ft',
#  'p banchero misses 2-pt jump shot from 3 ft',
#  'defensive rebound by n vučević',
#  'j giddey makes 3-pt jump shot from 24 ft',
#  'orlando full timeout',
#  'f wagner misses 2-pt hook shot from 9 ft',
#  'offensive rebound by f wagner',
#  'k caldwell-pope makes 3-pt jump shot from 25 ft assist by f wagner',
#  'z lavine misses 2-pt jump shot from 18 ft',
#  'defensive rebound by w carter',
#  'w carter makes 2-pt layup from 2 ft',
#  'p williams makes 3-pt jump shot from 27 ft assist by n vučević',
#  'turnover by p banchero lost ball steal by n vučević',
#  'p williams makes 3-pt jump shot from 25 ft assist by j giddey',
#  'w carter makes 2-pt dunk from 1 ft assist by j suggs',
#  'c white makes 3-pt jump shot from 27 ft assist by z lavine',
#  'j suggs misses 2-pt jump shot from 15 ft',
#  'defensive rebound by c white',
#  'j giddey makes 3-pt jump shot from 26 ft assist by c white',
#  'f wagner misses 2-pt jump shot from 8 ft',
#  'defensive rebound by p williams',
#  'personal foul by k caldwell-pope drawn by c white',
#  'g harris enters the game for f wagner',
#  'a dosunmu enters the game for c white',
#  'n vučević misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j suggs',
#  'j suggs misses 2-pt jump shot from 2 ft',
#  'defensive rebound by n vučević',
#  'j giddey makes 3-pt jump shot from 27 ft',
#  'orlando full timeout',
#  'a black enters the game for w carter',
#  'm wagner enters the game for j suggs',
#  'g harris misses 3-pt jump shot from 24 ft',
#  'defensive rebound by p williams',
#  'n vučević makes 2-pt hook shot from 6 ft assist by j giddey',
#  'turnover by a black out of bounds lost ball',
#  'j phillips enters the game for p williams',
#  'n vučević misses 3-pt jump shot from 26 ft',
#  'defensive rebound by m wagner',
#  'turnover by m wagner bad pass',
#  'j suggs enters the game for k caldwell-pope',
#  'c white enters the game for j giddey',
#  'n vučević makes 2-pt hook shot from 6 ft assist by z lavine',
#  'personal foul by j phillips drawn by p banchero',
#  'j suggs makes 2-pt jump shot from 17 ft',
#  'j phillips misses 3-pt jump shot from 23 ft',
#  'defensive rebound by m wagner',
#  'shooting foul by n vučević drawn by m wagner',
#  'm wagner makes free throw 1 of 2',
#  'j howard enters the game for j suggs',
#  'd terry enters the game for z lavine',
#  'm wagner makes free throw 2 of 2',
#  'c white misses 3-pt jump shot from 28 ft',
#  'defensive rebound by j howard',
#  'turnover by p banchero bad pass',
#  'a sanogo enters the game for n vučević',
#  'turnover by j phillips lost ball steal by a black',
#  'p banchero makes 2-pt layup from 1 ft assist by a black',
#  'd terry makes 2-pt layup from 2 ft assist by a sanogo',
#  'p banchero makes 3-pt jump shot from 26 ft assist by a black',
#  'a dosunmu misses 2-pt layup from 2 ft',
#  'offensive rebound by a sanogo',
#  'a sanogo misses 2-pt layup at rim',
#  'defensive rebound by p banchero',
#  'shooting foul by c white drawn by a black',
#  'a black makes free throw 1 of 2',
#  'j isaac enters the game for p banchero',
#  'p williams enters the game for j phillips',
#  'a black makes free throw 2 of 2',
#  'c white makes 3-pt jump shot from 26 ft assist by a dosunmu',
#  'j isaac makes 3-pt jump shot from 22 ft assist by m wagner',
#  'j suggs enters the game for j howard',
#  'turnover by team shot clock',
#  'g harris misses 2-pt jump shot from 13 ft',
#  'defensive rebound by a dosunmu',
#  'a sanogo misses 2-pt dunk from 1 ft block by a black',
#  'defensive rebound by g harris',
#  'j suggs makes 2-pt layup from 1 ft assist by g harris',
#  'personal take foul by j suggs drawn by c white',
#  'a sanogo makes 2-pt jump shot from 6 ft assist by a dosunmu',
#  'j suggs misses 3-pt jump shot from 37 ft',
#  'offensive rebound by team',
#  'm wagner misses 2-pt layup from 4 ft',
#  'defensive rebound by j giddey',
#  'd terry misses 3-pt jump shot from 26 ft',
#  'defensive rebound by j isaac',
#  'offensive foul by m wagner drawn by d terry',
#  'turnover by m wagner offensive foul',
#  'j phillips misses 3-pt jump shot from 23 ft',
#  'defensive rebound by a black',
#  'f wagner misses 3-pt jump shot from 27 ft',
#  'defensive rebound by j giddey',
#  'd terry misses 2-pt layup from 2 ft block by a black',
#  'defensive rebound by team',
#  'k caldwell-pope enters the game for f wagner',
#  't craig enters the game for a sanogo',
#  'j howard misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j giddey',
#  'turnover by j giddey bad pass steal by j isaac',
#  'j isaac misses 2-pt jump shot from 13 ft',
#  'defensive rebound by d terry',
#  'j giddey misses 2-pt jump shot from 22 ft',
#  'defensive rebound by j isaac',
#  'm wagner misses 2-pt layup from 2 ft',
#  'defensive rebound by t craig',
#  'd terry misses 2-pt layup from 2 ft',
#  'defensive rebound by j isaac',
#  'a black misses 2-pt layup from 2 ft',
#  'defensive rebound by j giddey',
#  't craig misses 3-pt jump shot from 24 ft',
#  'defensive rebound by team',
#  'loose ball foul by d terry drawn by j isaac',
#  'p banchero enters the game for j howard',
#  'j suggs enters the game for m wagner',
#  'z lavine enters the game for d terry',
#  'j isaac misses 3-pt jump shot from 24 ft',
#  'defensive rebound by j giddey',
#  'a dosunmu misses 3-pt jump shot from 26 ft block by a black',
#  'defensive rebound by a black',
#  'k caldwell-pope misses 3-pt jump shot from 27 ft',
#  'defensive rebound by t craig',
#  'j giddey misses 2-pt jump shot from 7 ft',
#  'defensive rebound by j suggs',
#  'turnover by j suggs lost ball steal by j giddey',
#  'shooting foul by a black drawn by j phillips',
#  'j phillips misses free throw 1 of 2',
#  'offensive rebound by team',
#  'w carter enters the game for j isaac',
#  'c white enters the game for a dosunmu',
#  'j phillips makes free throw 2 of 2',
#  'personal foul by t craig drawn by p banchero',
#  'a black misses 3-pt jump shot from 25 ft',
#  'defensive rebound by z lavine',
#  'shooting foul by p banchero drawn by z lavine',
#  'z lavine misses free throw 1 of 2',
#  'offensive rebound by team',
#  'a dosunmu enters the game for t craig',
#  'n vučević enters the game for j giddey',
#  'p williams enters the game for j phillips',
#  'z lavine makes free throw 2 of 2',
#  'p banchero misses 3-pt jump shot from 27 ft',
#  'offensive rebound by a black',
#  'p banchero misses 3-pt jump shot from 26 ft',
#  'defensive rebound by z lavine',
#  'z lavine misses 2-pt jump shot from 9 ft',
#  'defensive rebound by p banchero',
#  'p banchero misses 3-pt jump shot from 26 ft',
#  'defensive rebound by p williams',
#  'chicago full timeout',
#  'g harris enters the game for a black',
#  'p williams misses 2-pt jump shot from 17 ft',
#  'defensive rebound by w carter',
#  'p banchero misses 3-pt jump shot from 27 ft',
#  'defensive rebound by z lavine',
#  'shooting foul by w carter drawn by z lavine',
#  'z lavine makes free throw 1 of 2',
#  'z lavine makes free throw 2 of 2',
#  'shooting foul by n vučević drawn by w carter',
#  'w carter makes free throw 1 of 2',
#  'w carter makes free throw 2 of 2',
#  'c white misses 3-pt jump shot from 31 ft',
#  'defensive rebound by team',
#  'loose ball foul by c white drawn by j suggs',
#  'turnover by j suggs bad pass steal by p williams',
#  'a dosunmu makes 2-pt layup from 1 ft assist by n vučević',
#  'w carter misses 3-pt jump shot from 26 ft',
#  'defensive rebound by z lavine',
#  'turnover by c white lost ball steal by w carter',
#  'k caldwell-pope makes 2-pt dunk from 1 ft assist by w carter',
#  'n vučević makes 2-pt jump shot from 10 ft',
#  'shooting foul by n vučević drawn by w carter',
#  'w carter makes free throw 1 of 2',
#  'chicago full timeout',
#  'j giddey enters the game for a dosunmu',
#  'w carter makes free throw 2 of 2',
#  'n vučević misses 2-pt jump shot from 14 ft',
#  'offensive rebound by p williams',
#  'turnover by n vučević back court',
#  'orlando full timeout',
#  'orlando full timeout',
#  'a black enters the game for g harris',
#  'turnover by p banchero bad pass',
#  'shooting foul by k caldwell-pope drawn by z lavine',
#  'z lavine makes free throw 1 of 2',
#  'z lavine misses free throw 2 of 2',
#  'defensive rebound by w carter',
#  'p banchero makes 2-pt jump shot from 17 ft assist by j suggs',
#  'shooting foul by w carter drawn by n vučević',
#  'n vučević makes free throw 1 of 2',
#  'j isaac enters the game for w carter',
#  'n vučević makes free throw 2 of 2',
#  'p banchero misses 2-pt layup from 4 ft block by n vučević',
#  'defensive rebound by n vučević',
#  'offensive foul by n vučević drawn by k caldwell-pope',
#  'turnover by n vučević offensive foul',
#  'k caldwell-pope misses 3-pt jump shot from 23 ft',
#  'defensive rebound by j giddey',
#  'shooting foul by a black drawn by j giddey',
#  'j giddey misses free throw 1 of 2',
#  'offensive rebound by team',
#  'j giddey makes free throw 2 of 2',
#  'a black makes 2-pt layup from 1 ft assist by j isaac',
#  'p williams makes 3-pt jump shot from 24 ft assist by j giddey',
#  'j isaac misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j giddey',
#  'turnover by z lavine bad pass',
#  'orlando full timeout',
#  'w carter enters the game for j isaac',
#  'a dosunmu enters the game for c white',
#  'p banchero makes 2-pt layup from 1 ft',
#  'chicago full timeout',
#  'j isaac enters the game for w carter',
#  'c white enters the game for a dosunmu',
#  'chicago full timeout',
#  'turnover by p williams out of bounds lost ball',
#  'g harris enters the game for j isaac',
#  'a dosunmu enters the game for n vučević',
#  'j suggs misses 2-pt jump shot from 13 ft',
#  'defensive rebound by z lavine',
#  'personal foul by a black drawn by j giddey',
#  'j giddey misses free throw 1 of 2',
#  'offensive rebound by team',
#  'j giddey makes free throw 2 of 2',
#  'orlando full timeout',
#  'turnover by r barrett bad pass steal by n richards',
#  's curry makes 2-pt jump shot from 17 ft assist by m bridges',
#  'd mitchell misses 3-pt jump shot from 27 ft',
#  'defensive rebound by n richards',
#  'm bridges misses 2-pt layup from 3 ft',
#  'defensive rebound by j poeltl',
#  'r barrett misses 2-pt layup from 3 ft',
#  'defensive rebound by m bridges',
#  'm bridges misses 2-pt layup from 3 ft block by j mogbo',
#  'defensive rebound by team',
#  'turnover by r barrett out of bounds lost ball',
#  'm bridges makes 2-pt layup from 3 ft assist by l ball',
#  'j poeltl misses 2-pt jump shot from 8 ft',
#  'defensive rebound by n richards',
#  'j green makes 3-pt jump shot from 23 ft assist by l ball',
#  'turnover by j poeltl lost ball steal by l ball',
#  'n richards makes 2-pt dunk from 2 ft assist by j green',
#  'toronto full timeout',
#  'j poeltl makes 2-pt dunk from 2 ft assist by r barrett',
#  'n richards misses 2-pt layup from 1 ft',
#  'defensive rebound by r barrett',
#  'j poeltl misses 2-pt layup from 3 ft',
#  'defensive rebound by l ball',
#  'j green misses 2-pt jump shot from 13 ft',
#  'offensive rebound by n richards',
#  'personal foul by j poeltl drawn by n richards',
#  'personal foul by d mitchell drawn by l ball',
#  'm bridges misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j poeltl',
#  'g dick makes 3-pt jump shot from 26 ft assist by d mitchell',
#  'turnover by l ball bad pass steal by g dick',
#  'r barrett misses 3-pt jump shot from 26 ft block by j green',
#  'defensive rebound by l ball',
#  'turnover by l ball bad pass steal by r barrett',
#  'j mogbo makes 2-pt dunk from 1 ft assist by r barrett',
#  'charlotte full timeout',
#  't mann enters the game for l ball',
#  'c martin enters the game for j green',
#  't mann misses 2-pt layup from 3 ft',
#  'offensive rebound by n richards',
#  'n richards makes 2-pt dunk at rim',
#  'offensive foul by d mitchell drawn by c martin',
#  'turnover by d mitchell offensive foul',
#  'n richards misses 2-pt layup from 2 ft',
#  'offensive rebound by n richards',
#  'm bridges misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j poeltl',
#  'd mitchell misses 3-pt jump shot from 26 ft',
#  'offensive rebound by team',
#  'loose ball foul by t mann drawn by j poeltl',
#  'o agbaji enters the game for r barrett',
#  'j shead enters the game for d mitchell',
#  'g williams enters the game for m bridges',
#  'j mogbo misses 2-pt jump shot from 10 ft',
#  'offensive rebound by j mogbo',
#  'j mogbo makes 2-pt dunk at rim',
#  'turnover by s curry bad pass steal by j mogbo',
#  'g dick makes 2-pt layup from 3 ft assist by j mogbo',
#  'n richards misses 2-pt hook shot from 1 ft',
#  'defensive rebound by j shead',
#  'j shead misses 2-pt layup from 3 ft block by t mann',
#  'defensive rebound by n richards',
#  'offensive foul by g williams drawn by j shead',
#  'turnover by g williams offensive foul',
#  'c boucher enters the game for j mogbo',
#  'm diabaté enters the game for s curry',
#  't salaün  enters the game for n richards',
#  'turnover by g dick bad pass steal by t salaün ',
#  'g williams makes 2-pt layup from 2 ft assist by t salaün ',
#  'c boucher misses 3-pt jump shot from 27 ft',
#  'defensive rebound by c martin',
#  't salaün  misses 3-pt jump shot from 24 ft',
#  'defensive rebound by c boucher',
#  'o agbaji makes 2-pt layup from 2 ft assist by c boucher',
#  't mann makes 2-pt jump shot from 16 ft assist by t salaün ',
#  'shooting foul by j shead drawn by t mann',
#  'j battle enters the game for g dick',
#  't mann makes free throw 1 of 1',
#  'loose ball foul by c martin drawn by j battle',
#  'b fernando enters the game for j poeltl',
#  'j shead misses 2-pt jump shot from 11 ft',
#  'offensive rebound by b fernando',
#  'j shead misses 3-pt jump shot from 27 ft',
#  'defensive rebound by m diabaté',
#  't salaün  misses 3-pt jump shot from 27 ft',
#  'offensive rebound by m diabaté',
#  't mann makes 3-pt jump shot from 29 ft assist by m diabaté',
#  'c boucher misses 2-pt jump shot from 15 ft',
#  'defensive rebound by g williams',
#  'c martin makes 3-pt jump shot from 24 ft assist by g williams',
#  'toronto full timeout',
#  'r barrett enters the game for c boucher',
#  'turnover by o agbaji step out of bounds',
#  'c martin makes 2-pt jump shot from 16 ft',
#  'r barrett misses 2-pt layup from 5 ft',
#  'defensive rebound by m diabaté',
#  't mann makes 2-pt jump shot from 8 ft',
#  'j battle misses 3-pt jump shot from 27 ft',
#  'offensive rebound by team',
#  'l ball enters the game for m diabaté',
#  'r barrett misses 2-pt jump shot from 6 ft',
#  'offensive rebound by j shead',
#  'r barrett makes 2-pt layup from 3 ft assist by j shead',
#  't mann makes 2-pt layup from 3 ft',
#  'turnover by r barrett bad pass steal by c martin',
#  'personal foul by b fernando drawn by t mann',
#  'j mogbo enters the game for b fernando',
#  'l ball misses 2-pt jump shot from 19 ft',
#  'defensive rebound by j mogbo',
#  'shooting foul by t mann drawn by j mogbo',
#  'j mogbo makes free throw 1 of 2',
#  'j mogbo misses free throw 2 of 2',
#  'defensive rebound by t salaün ',
#  'g williams makes 2-pt layup from 1 ft assist by l ball',
#  'l ball misses 3-pt jump shot from 26 ft',
#  'offensive rebound by g williams',
#  'n richards makes 2-pt jump shot from 7 ft assist by g williams',
#  'offensive foul by j mogbo drawn by j green',
#  'turnover by j mogbo offensive foul',
#  'charlotte full timeout',
#  'instant replay challenge: ruling stands',
#  'j green makes 3-pt jump shot from 23 ft assist by n richards',
#  'j mogbo makes 2-pt dunk from 2 ft assist by r barrett',
#  'l ball misses 3-pt jump shot from 24 ft',
#  'defensive rebound by j mogbo',
#  'j mogbo misses 2-pt layup from 3 ft block by j green',
#  'offensive rebound by team',
#  'r barrett makes 2-pt layup from 2 ft',
#  'n richards makes 2-pt jump shot from 5 ft assist by j green',
#  'o agbaji misses 3-pt jump shot from 23 ft',
#  'offensive rebound by j mogbo',
#  'j battle misses 3-pt jump shot from 27 ft',
#  'defensive rebound by n richards',
#  's curry misses 3-pt jump shot from 26 ft',
#  'defensive rebound by r barrett',
#  'shooting foul by j green drawn by r barrett',
#  'r barrett misses free throw 1 of 2',
#  'offensive rebound by team',
#  'g dick enters the game for o agbaji',
#  'j poeltl enters the game for j mogbo',
#  'm bridges enters the game for g williams',
#  'r barrett makes free throw 2 of 2',
#  'l ball makes 2-pt jump shot from 4 ft assist by n richards',
#  'shooting foul by g dick drawn by l ball',
#  'l ball makes free throw 1 of 1',
#  'r barrett makes 3-pt jump shot from 26 ft assist by d mitchell',
#  'l ball makes 3-pt jump shot from 29 ft',
#  'g dick misses 2-pt layup from 2 ft',
#  'defensive rebound by n richards',
#  'n richards makes 2-pt layup from 3 ft',
#  'shooting foul by j poeltl drawn by n richards',
#  'c boucher enters the game for j battle',
#  'j shead enters the game for d mitchell',
#  'n richards misses free throw 1 of 1',
#  'defensive rebound by j poeltl',
#  'personal foul by l ball drawn by r barrett',
#  'j poeltl makes 2-pt layup from 3 ft assist by j shead',
#  'l ball makes 3-pt jump shot from 28 ft assist by n richards',
#  'j poeltl makes 2-pt layup from 3 ft assist by r barrett',
#  'l ball makes 3-pt jump shot from 26 ft assist by j green',
#  'g dick makes 3-pt jump shot from 23 ft assist by j shead',
#  'l ball misses 3-pt jump shot from 28 ft',
#  'offensive rebound by j green',
#  'j green makes 3-pt jump shot from 25 ft assist by s curry',
#  'j shead makes 3-pt jump shot from 28 ft assist by r barrett',
#  'turnover by l ball bad pass',
#  't mann enters the game for l ball',
#  't salaün  enters the game for j green',
#  'g dick makes 2-pt layup from 3 ft assist by r barrett',
#  'm bridges misses 2-pt layup from 3 ft',
#  'defensive rebound by j poeltl',
#  'r barrett makes 3-pt jump shot from 26 ft assist by j shead',
#  'turnover by t mann lost ball steal by j shead',
#  'g dick makes 2-pt dunk from 2 ft assist by j shead',
#  'turnover by m bridges bad pass',
#  'c martin enters the game for s curry',
#  'personal foul by c martin drawn by g dick',
#  'g dick makes 2-pt jump shot from 14 ft assist by r barrett',
#  't mann misses 3-pt jump shot from 27 ft',
#  'defensive rebound by j poeltl',
#  'c boucher makes 2-pt dunk from 2 ft assist by j shead',
#  't mann makes 2-pt jump shot from 3 ft',
#  'toronto full timeout',
#  'o agbaji enters the game for r barrett',
#  'l ball enters the game for m bridges',
#  'g williams enters the game for n richards',
#  'shooting foul by g williams drawn by g dick',
#  'g dick misses free throw 1 of 2',
#  'offensive rebound by team',
#  'g dick makes free throw 2 of 2',
#  'l ball misses 2-pt layup from 5 ft block by c boucher',
#  'defensive rebound by o agbaji',
#  'g dick misses 3-pt jump shot from 27 ft',
#  'offensive rebound by j poeltl',
#  'o agbaji makes 3-pt jump shot from 23 ft assist by j poeltl',
#  'g williams makes 3-pt jump shot from 26 ft assist by t mann',
#  'j shead makes 2-pt jump shot from 9 ft',
#  'g williams misses 3-pt jump shot from 25 ft',
#  'offensive rebound by t salaün ',
#  't salaün  makes 2-pt jump shot from 5 ft',
#  'c boucher makes 2-pt layup from 3 ft assist by j shead',
#  't mann misses 3-pt jump shot from 28 ft',
#  'defensive rebound by c boucher',
#  'g dick makes 2-pt layup from 3 ft assist by j shead',
#  'c martin misses 3-pt jump shot from 25 ft',
#  'defensive rebound by j poeltl',
#  'turnover by c boucher lost ball steal by g williams',
#  't mann makes 3-pt jump shot from 23 ft assist by g williams',
#  'shooting foul by t mann drawn by o agbaji',
#  'o agbaji makes free throw 1 of 2',
#  'd mitchell enters the game for j shead',
#  's curry enters the game for t mann',
#  'j green enters the game for c martin',
#  'n richards enters the game for t salaün ',
#  'o agbaji makes free throw 2 of 2',
#  'turnover by g williams lost ball steal by g dick',
#  'c boucher makes 2-pt dunk from 1 ft assist by o agbaji',
#  'r barrett enters the game for c boucher',
#  'j mogbo enters the game for g dick',
#  'm bridges enters the game for g williams',
#  'violation by team kicked ball',
#  'l ball misses 2-pt jump shot from 12 ft',
#  'offensive rebound by team',
#  'turnover by l ball bad pass',
#  'd mitchell misses 3-pt jump shot from 25 ft',
#  'defensive rebound by m bridges',
#  'l ball misses 3-pt jump shot from 25 ft',
#  'offensive rebound by s curry',
#  'l ball misses 2-pt jump shot from 4 ft',
#  'offensive rebound by n richards',
#  'n richards makes 2-pt layup from 2 ft',
#  'shooting foul by r barrett drawn by n richards',
#  'n richards makes free throw 1 of 1',
#  'j poeltl makes 2-pt jump shot from 10 ft assist by d mitchell',
#  'j green misses 2-pt layup from 3 ft',
#  'defensive rebound by j poeltl',
#  'j mogbo makes 2-pt layup from 2 ft assist by d mitchell',
#  'personal foul by g dick drawn by s curry',
#  's curry misses 2-pt jump shot from 15 ft',
#  'offensive rebound by n richards',
#  'n richards makes 2-pt layup at rim',
#  'r barrett makes 2-pt jump shot from 8 ft',
#  's curry makes 3-pt jump shot from 23 ft assist by l ball',
#  'g dick makes 2-pt jump shot from 14 ft assist by d mitchell',
#  'm bridges makes 3-pt jump shot from 26 ft assist by n richards',
#  'd mitchell misses 3-pt jump shot from 25 ft',
#  'offensive rebound by j poeltl',
#  'j poeltl makes 2-pt layup from 1 ft',
#  'turnover by s curry bad pass steal by j poeltl',
#  'd mitchell misses 2-pt layup from 1 ft block by m bridges',
#  'defensive rebound by j green',
#  'turnover by m bridges bad pass steal by j poeltl',
#  'j mogbo makes 2-pt layup from 1 ft assist by r barrett',
#  'm bridges misses 3-pt jump shot from 27 ft',
#  'defensive rebound by r barrett',
#  'shooting foul by l ball drawn by r barrett',
#  'r barrett makes free throw 1 of 2',
#  'charlotte full timeout',
#  'r barrett misses free throw 2 of 2',
#  'defensive rebound by n richards',
#  'shooting foul by r barrett drawn by s curry',
#  's curry makes free throw 1 of 2',
#  's curry makes free throw 2 of 2',
#  'd mitchell makes 2-pt layup from 1 ft',
#  'm bridges misses 3-pt jump shot from 27 ft',
#  'defensive rebound by d mitchell',
#  'r barrett misses 2-pt jump shot from 4 ft',
#  'offensive rebound by j poeltl',
#  'j poeltl makes 2-pt layup at rim',
#  'l ball misses 2-pt layup from 3 ft',
#  'offensive rebound by n richards',
#  'shooting foul by j poeltl drawn by n richards',
#  'n richards misses free throw 1 of 2',
#  'offensive rebound by team',
#  'o agbaji enters the game for r barrett',
#  'c boucher enters the game for j mogbo',
#  't mann enters the game for l ball',
#  'c martin enters the game for j green',
#  'n richards misses free throw 2 of 2',
#  'defensive rebound by c boucher',
#  'c boucher misses 3-pt jump shot from 25 ft',
#  'offensive rebound by d mitchell',
#  'c boucher misses 3-pt jump shot from 25 ft',
#  'offensive rebound by j poeltl',
#  'j poeltl misses 2-pt layup from 2 ft block by n richards',
#  'offensive rebound by g dick',
#  'g dick makes 2-pt layup at rim',
#  'turnover by t mann lost ball steal by g dick',
#  'o agbaji misses 2-pt layup from 3 ft block by n richards',
#  'offensive rebound by c boucher',
#  'c boucher makes 2-pt dunk at rim',
#  'c martin makes 2-pt jump shot from 2 ft',
#  'shooting foul by n richards drawn by g dick',
#  'g dick makes free throw 1 of 2',
#  'm diabaté enters the game for m bridges',
#  't salaün  enters the game for s curry',
#  'g williams enters the game for n richards',
#  'g dick makes free throw 2 of 2',
#  'g williams makes 3-pt jump shot from 27 ft assist by c martin',
#  'j poeltl makes 2-pt layup from 3 ft assist by d mitchell',
#  'c martin makes 3-pt jump shot from 26 ft assist by t salaün ',
#  'j poeltl makes 2-pt layup from 3 ft assist by d mitchell',
#  'c martin makes 2-pt layup from 3 ft',
#  'o agbaji makes 2-pt layup from 3 ft assist by d mitchell',
#  'shooting foul by m diabaté drawn by o agbaji',
#  'j battle enters the game for g dick',
#  'j mogbo enters the game for d mitchell',
#  'j shead enters the game for j poeltl',
#  'o agbaji makes free throw 1 of 1',
#  't mann misses 2-pt jump shot from 9 ft',
#  'defensive rebound by j battle',
#  'c boucher makes 2-pt dunk from 2 ft assist by j shead',
#  'personal foul by c boucher drawn by g williams',
#  'g williams makes free throw 1 of 2',
#  'toronto full timeout',
#  'g williams makes free throw 2 of 2',
#  'c boucher makes 3-pt jump shot from 23 ft assist by o agbaji',
#  't mann makes 2-pt layup from 2 ft',
#  'o agbaji misses 3-pt jump shot from 26 ft',
#  'offensive rebound by team',
#  'loose ball foul by c martin drawn by j battle',
#  'shooting foul by c martin drawn by j shead',
#  'j shead misses free throw 1 of 3',
#  'offensive rebound by team',
#  'j shead makes free throw 2 of 3',
#  'l ball enters the game for c martin',
#  'j shead makes free throw 3 of 3',
#  'l ball makes 2-pt jump shot from 8 ft assist by g williams',
#  'j shead misses 2-pt layup from 4 ft',
#  'defensive rebound by m diabaté',
#  'l ball misses 3-pt jump shot from 29 ft',
#  'defensive rebound by j battle',
#  'turnover by o agbaji lost ball steal by t mann',
#  'l ball makes 3-pt jump shot from 23 ft assist by t mann',
#  'turnover by j shead bad pass steal by t mann',
#  'shooting foul by j battle drawn by t salaün ',
#  't salaün  misses free throw 1 of 2',
#  'offensive rebound by team',
#  'r barrett enters the game for j battle',
#  'd mitchell enters the game for j shead',
#  't salaün  makes free throw 2 of 2',
#  'turnover by d mitchell bad pass steal by l ball',
#  't mann makes 3-pt jump shot from 26 ft assist by l ball',
#  'toronto full timeout',
#  'g dick enters the game for c boucher',
#  'c martin enters the game for t mann',
#  'turnover by g dick lost ball steal by g williams',
#  'c martin makes 3-pt jump shot from 23 ft assist by g williams',
#  'g dick misses 3-pt jump shot from 26 ft',
#  'defensive rebound by t salaün ',
#  'l ball misses 3-pt jump shot from 56 ft',
#  'offensive rebound by team',
#  'shooting foul by g williams drawn by r barrett',
#  'r barrett misses free throw 1 of 2',
#  'offensive rebound by team',
#  'r barrett makes free throw 2 of 2',
#  'g williams makes 3-pt jump shot from 23 ft assist by t mann',
#  'g dick misses 3-pt jump shot from 25 ft',
#  'defensive rebound by l ball',
#  't mann makes 3-pt jump shot from 23 ft assist by l ball',
#  'r barrett misses 2-pt layup from 5 ft block by n richards',
#  'offensive rebound by r barrett',
#  'shooting foul by n richards drawn by r barrett',
#  'r barrett makes free throw 1 of 2',
#  'm bridges enters the game for g williams',
#  'r barrett makes free throw 2 of 2',
#  'j green misses 3-pt jump shot from 23 ft',
#  'defensive rebound by j poeltl',
#  'personal foul by j green drawn by g dick',
#  'shooting foul by j green drawn by g dick',
#  'g dick misses free throw 1 of 2',
#  'offensive rebound by team',
#  'g dick makes free throw 2 of 2',
#  't mann makes 2-pt jump shot from 5 ft',
#  'r barrett misses 2-pt layup from 2 ft',
#  'offensive rebound by j poeltl',
#  'j poeltl makes 2-pt dunk from 2 ft',
#  'personal foul by j poeltl drawn by t mann',
#  't mann misses 2-pt layup from 4 ft block by o agbaji',
#  'offensive rebound by team',
#  'j battle enters the game for g dick',
#  'm bridges misses 3-pt jump shot from 23 ft',
#  'offensive rebound by team',
#  'loose ball foul by d mitchell drawn by l ball',
#  'l ball misses 3-pt jump shot from 23 ft',
#  'defensive rebound by j poeltl',
#  'j poeltl makes 2-pt layup from 3 ft assist by d mitchell',
#  't mann misses 3-pt jump shot from 23 ft',
#  'defensive rebound by j battle',
#  'shooting foul by t mann drawn by r barrett',
#  'r barrett misses free throw 1 of 2',
#  'offensive rebound by team',
#  'charlotte full timeout',
#  'j mogbo enters the game for o agbaji',
#  's curry enters the game for j green',
#  'c martin enters the game for t mann',
#  'r barrett misses free throw 2 of 2',
#  'defensive rebound by c martin',
#  'personal foul by j battle drawn by s curry',
#  'turnover by l ball bad pass steal by r barrett',
#  'r barrett makes 2-pt layup from 1 ft',
#  'c martin makes 2-pt jump shot from 14 ft',
#  'j poeltl misses 2-pt hook shot from 7 ft',
#  'defensive rebound by m bridges',
#  'offensive foul by l ball drawn by r barrett',
#  'turnover by l ball offensive foul',
#  'instant replay challenge: ruling stands',
#  'toronto full timeout',
#  'g dick enters the game for r barrett',
#  'g dick misses 2-pt layup from 2 ft block by n richards',
#  'defensive rebound by c martin',
#  'n richards misses 2-pt layup from 3 ft block by j mogbo',
#  'defensive rebound by j poeltl',
#  'd mitchell makes 2-pt layup from 1 ft assist by j poeltl',
#  'm bridges misses 3-pt jump shot from 24 ft',
#  'offensive rebound by s curry',
#  'l ball misses 3-pt jump shot from 23 ft',
#  'offensive rebound by n richards',
#  'n richards makes 2-pt layup at rim',
#  'd mitchell makes 2-pt jump shot from 9 ft',
#  'shooting foul by j mogbo drawn by m bridges',
#  'm bridges makes free throw 1 of 2',
#  'o agbaji enters the game for j battle',
#  'r barrett enters the game for d mitchell',
#  'j shead enters the game for j poeltl',
#  't mann enters the game for l ball',
#  'm bridges makes free throw 2 of 2',
#  'g dick misses 3-pt jump shot from 26 ft',
#  'defensive rebound by n richards',
#  'n richards makes 2-pt layup from 2 ft assist by m bridges',
#  'g dick makes 2-pt jump shot from 14 ft assist by j mogbo',
#  'offensive foul by n richards drawn by j shead',
#  'turnover by n richards offensive foul',
#  'g williams enters the game for m bridges',
#  'r barrett makes 2-pt layup from 7 ft',
#  't mann misses 2-pt jump shot from 14 ft',
#  'defensive rebound by o agbaji',
#  'offensive foul by g dick drawn by s curry',
#  'turnover by g dick offensive foul',
#  'c martin makes 3-pt jump shot from 26 ft assist by t mann',
#  'r barrett misses 3-pt jump shot from 26 ft',
#  'defensive rebound by t mann',
#  't mann misses 3-pt jump shot from 30 ft',
#  'offensive rebound by c martin',
#  'c martin makes 2-pt layup at rim',
#  'shooting foul by t mann drawn by g dick',
#  'g dick makes free throw 1 of 2',
#  'd mitchell enters the game for j mogbo',
#  'j poeltl enters the game for j shead',
#  'l ball enters the game for s curry',
#  'g dick makes free throw 2 of 2',
#  'n richards makes 2-pt layup from 2 ft assist by c martin',
#  'shooting foul by o agbaji drawn by n richards',
#  'n richards makes free throw 1 of 1',
#  'shooting foul by g williams drawn by r barrett',
#  'r barrett makes free throw 1 of 2',
#  'r barrett makes free throw 2 of 2',
#  'j green enters the game for g williams',
#  't mann misses 2-pt layup from 5 ft block by o agbaji',
#  'defensive rebound by g dick',
#  'r barrett makes 3-pt jump shot from 25 ft assist by g dick',
#  'shooting foul by d mitchell drawn by n richards',
#  'n richards makes free throw 1 of 2',
#  'n richards makes free throw 2 of 2',
#  'r barrett makes 3-pt jump shot from 25 ft assist by d mitchell',
#  'personal foul by g dick drawn by c martin',
#  'c martin makes free throw 1 of 2',
#  'c martin misses free throw 2 of 2',
#  'defensive rebound by o agbaji',
#  'personal foul by l ball drawn by d mitchell',
#  'd mitchell misses free throw 1 of 2',
#  'offensive rebound by team',
#  'g williams enters the game for n richards',
#  'd mitchell makes free throw 2 of 2',
#  'c martin misses 3-pt jump shot from 23 ft',
#  'offensive rebound by team',
#  'turnover by team shot clock',
#  'd mitchell makes 2-pt layup from 1 ft',
#  'l ball makes 2-pt layup from 2 ft',
#  'r barrett makes 2-pt layup from 2 ft assist by d mitchell',
#  'personal foul by r barrett drawn by t mann',
#  't mann makes free throw 1 of 2',
#  't mann makes free throw 2 of 2',
#  'd mitchell makes 2-pt layup from 1 ft',
#  'personal take foul by g dick drawn by c martin',
#  'c martin makes free throw 1 of 2',
#  'c martin makes free throw 2 of 2',
#  'toronto full timeout',
#  'g dick makes 2-pt layup from 1 ft assist by o agbaji',
#  'personal take foul by g dick drawn by g williams',
#  'c boucher enters the game for g dick',
#  'g williams makes free throw 1 of 2',
#  'g williams makes free throw 2 of 2',
#  'd mitchell misses 3-pt jump shot from 50 ft',
#  'offensive rebound by team',
#  'a reaves makes 2-pt jump shot from 17 ft assist by d russell',
#  'turnover by d garland bad pass steal by a davis',
#  'l james makes 2-pt dunk from 1 ft assist by d russell',
#  'd mitchell makes 2-pt layup from 1 ft',
#  'shooting foul by d garland drawn by d russell',
#  'd russell makes free throw 1 of 2',
#  'd russell makes free throw 2 of 2',
#  'personal foul by r hachimura drawn by j allen',
#  'd mitchell makes 3-pt jump shot from 24 ft assist by d garland',
#  'a davis makes 2-pt layup from 1 ft assist by d russell',
#  'd mitchell makes 2-pt jump shot from 14 ft',
#  'personal foul by d garland drawn by d russell',
#  'personal foul by d mitchell drawn by a reaves',
#  'c levert enters the game for d garland',
#  'l james misses 2-pt layup from 2 ft',
#  'defensive rebound by j allen',
#  'e mobley makes 2-pt dunk from 2 ft assist by d mitchell',
#  'r hachimura makes 2-pt layup from 1 ft assist by d russell',
#  'e mobley makes 2-pt jump shot at rim assist by c levert',
#  'a reaves makes 3-pt jump shot from 28 ft assist by a davis',
#  'd mitchell misses 3-pt jump shot from 25 ft',
#  'defensive rebound by d russell',
#  'd russell misses 3-pt jump shot from 27 ft',
#  'defensive rebound by j allen',
#  'd wade makes 3-pt jump shot from 24 ft assist by d mitchell',
#  'a davis makes 2-pt hook shot from 2 ft',
#  'shooting foul by e mobley drawn by a davis',
#  'a davis misses free throw 1 of 1',
#  'defensive rebound by e mobley',
#  'turnover by e mobley bad pass steal by a davis',
#  'turnover by a davis bad pass steal by d wade',
#  'd mitchell makes 3-pt jump shot from 26 ft',
#  'turnover by a davis bad pass steal by d mitchell',
#  'd mitchell makes 3-pt jump shot from 25 ft assist by c levert',
#  'la lakers full timeout',
#  'm christie enters the game for l james',
#  's merrill enters the game for e mobley',
#  'turnover by a davis traveling',
#  'd wade makes 3-pt jump shot from 25 ft assist by d mitchell',
#  'a reaves misses 3-pt jump shot from 26 ft',
#  'defensive rebound by j allen',
#  'd mitchell misses 3-pt jump shot from 26 ft',
#  'defensive rebound by r hachimura',
#  'turnover by r hachimura bad pass steal by d mitchell',
#  's merrill makes 3-pt jump shot from 29 ft assist by c levert',
#  'la lakers full timeout',
#  ...]

# %%
# Função para separar jogadas que tenham a palavra desejada
from nltk.tokenize import word_tokenize

def wanted_word_list(words_list, wanted_word):
    
    wanted_list = [i for i in words_list if wanted_word in i]
    wanted_list = [word_tokenize(i) for i in wanted_list]
    
    return wanted_list

# %%
#Função para entender o número máximos de palavra de cada lista
from collections import Counter

def find_max_words(words_list):
    num_palavras = [len(sublista) for sublista in words_list]
    contagem = Counter(num_palavras)
    return max(contagem.keys())

# %%
#Função para criar colunas
def columns_def(max_w):
    columns_list = []
    for i in range(1,max_w+1):
        columns_list.append(f"word{i}")
    return columns_list

# %% [markdown]
# ### Exploranddo as palavras que mais se repetem

# %%
plays_list_token = [word_tokenize(i) for i in plays_list]
plays_df = pd.DataFrame(plays_list_token)
plays_df
# Out:
#               0              1        2     3       4     5     6        7   \
# 0              k  caldwell-pope    makes  3-pt    jump  shot  from       26
# 1              j         giddey    makes  2-pt    jump  shot  from       20
# 2              p       banchero   misses  2-pt    jump  shot  from        6
# 3      defensive        rebound       by     j  giddey  None  None     None
# 4              p       williams   misses  2-pt   layup  from     2       ft
# ...          ...            ...      ...   ...     ...   ...   ...      ...
# 31152          d           bane    makes  free   throw     1    of        2
# 31153          d           bane    makes  free   throw     2    of        2
# 31154       utah           full  timeout  None    None  None  None     None
# 31155          c         sexton   enters   the    game   for     w  kessler
# 31156          l      markkanen    makes  3-pt    jump  shot  from       27
#
#          8       9     10    11        12
# 0        ft  assist    by     p  banchero
# 1        ft    None  None  None      None
# 2        ft    None  None  None      None
# 3      None    None  None  None      None
# 4      None    None  None  None      None
# ...     ...     ...   ...   ...       ...
# 31152  None    None  None  None      None
# 31153  None    None  None  None      None
# 31154  None    None  None  None      None
# 31155  None    None  None  None      None
# 31156    ft  assist    by     k    george
#
# [31157 rows x 13 columns]

# %%
plays_col = plays_df.columns.to_list()
fig, axs = plt.subplots(nrows=len(plays_col), ncols=1, figsize=(10, 30))

# Loop para criar os gráficos
for n, col in enumerate(plays_col):
    
    # Não precisa converter o índice 'n' em índices de linha, já que row = n
    row = n  # Cada subplot em uma nova linha
    
    top5_words = plays_df[col].value_counts(normalize=True)[0:10]
    sns.barplot(x=top5_words.index, y=top5_words.values, ax=axs[row])
    axs[row].set_title(col)  # Adicione um título ao gráfico

plt.tight_layout()  # Para melhorar a disposição dos gráficos
plt.show()

# %%
top5_words = plays_df[0].value_counts(normalize=True)[0:10]
top5_words
# Out:
# defensive    0.148666
# j            0.118625
# offensive    0.084540
# d            0.068299
# turnover     0.063774
# c            0.045864
# shooting     0.044902
# t            0.042270
# a            0.040569
# k            0.040087
# Name: 0, dtype: float64

# %% [markdown]
# ## Colunas iniciais

# %% [markdown]
# Criando o dicionário que servirá de base para a base de dados tabular do play-by-play

# %% [markdown]
# Todas as jogadas contarão com essa informaçoes

# %%
pbp_tab_data = {
    'key' : [],
    'quarter' : [],
    'time' : [],
    'team' : [],
    'player': [],
    'PTS': []
}

# %% [markdown]
# ## Arremessos feitos

# %%
makes_list = wanted_word_list(plays_list, 'makes')
max_words_make_list = find_max_words(makes_list)
columns_make_list = columns_def(max_words_make_list)

# %%
makes_df = pd.DataFrame(makes_list, columns=columns_make_list)
makes_df
# Out:
#      word1          word2  word3 word4  word5 word6 word7 word8   word9  \
# 0        k  caldwell-pope  makes  3-pt   jump  shot  from    26      ft
# 1        j         giddey  makes  2-pt   jump  shot  from    20      ft
# 2        p       banchero  makes  2-pt   jump  shot  from    22      ft
# 3        f         wagner  makes  2-pt  layup  from     1    ft  assist
# 4        p       banchero  makes  2-pt  layup    at   rim  None    None
# ...    ...            ...    ...   ...    ...   ...   ...   ...     ...
# 7780     k         george  makes  free  throw     1    of     2    None
# 7781     k         george  makes  free  throw     2    of     2    None
# 7782     d           bane  makes  free  throw     1    of     2    None
# 7783     d           bane  makes  free  throw     2    of     2    None
# 7784     l      markkanen  makes  3-pt   jump  shot  from    27      ft
#
#       word10 word11    word12    word13
# 0     assist     by         p  banchero
# 1       None   None      None      None
# 2     assist     by         w    carter
# 3         by      p  banchero      None
# 4       None   None      None      None
# ...      ...    ...       ...       ...
# 7780    None   None      None      None
# 7781    None   None      None      None
# 7782    None   None      None      None
# 7783    None   None      None      None
# 7784  assist     by         k    george
#
# [7785 rows x 13 columns]

# %%
# # Configuração das subplots

fig, axs = plt.subplots(nrows=math.ceil(len(columns_make_list)/2), ncols=2, figsize=(10, 30))

# Loop para criar os gráficos
for n, col in enumerate(columns_make_list):
    
    # Converter o índice 'n' em índices de linha e coluna
    row = n // 2
    col_idx = n % 2
    
    top5_words = makes_df[col].value_counts(normalize=True)[0:10]
    sns.barplot(x=top5_words.index, y=top5_words.values, ax=axs[row, col_idx])

# %% [markdown]
# ### Palavras a serem adicionadas

# %%
# Colunas necessárias 
pbp_tab_data['2PA'] = []
pbp_tab_data['2PM'] = []
pbp_tab_data['3PA'] = []
pbp_tab_data['3PM'] = []
pbp_tab_data['FTA'] = []
pbp_tab_data['FTM'] = []
pbp_tab_data['DUNK'] = []
pbp_tab_data['LAYUP'] = []
pbp_tab_data['HOOK'] = []
pbp_tab_data['JUMP'] = []
pbp_tab_data['shoot_dist'] = []
pbp_tab_data['AST'] = []
pbp_tab_data['AST_by'] = []
pbp_tab_data['AST_to'] = []
pbp_tab_data['technical'] = []
pbp_tab_data['flagrant'] = []
pbp_tab_data['clear_path'] = []

pbp_tab_data
# Out:
# {'key': [],
#  'quarter': [],
#  'time': [],
#  'team': [],
#  'player': [],
#  'PTS': [],
#  '2PA': [],
#  '2PM': [],
#  '3PA': [],
#  '3PM': [],
#  'FTA': [],
#  'FTM': [],
#  'DUNK': [],
#  'LAYUP': [],
#  'HOOK': [],
#  'JUMP': [],
#  'shoot_dist': [],
#  'AST': [],
#  'AST_by': [],
#  'AST_to': [],
#  'technical': [],
#  'flagrant': [],
#  'clear_path': []}

# %% [markdown]
# ## Arremessos perdidos

# %%
misses_list = wanted_word_list(plays_list, 'misses')
max_words_miss_list = find_max_words(misses_list)
columns_misses_list = columns_def(max_words_miss_list)

# %%
misses_df = pd.DataFrame(misses_list, columns=columns_misses_list)
misses_df
# Out:
#      word1      word2   word3 word4  word5 word6 word7 word8 word9 word10  \
# 0        p   banchero  misses  2-pt   jump  shot  from     6    ft   None
# 1        p   williams  misses  2-pt  layup  from     2    ft  None   None
# 2        p   williams  misses  3-pt   jump  shot  from    26    ft   None
# 3        c      white  misses  3-pt   jump  shot  from    25    ft   None
# 4        n    vučević  misses  2-pt  layup  from     2    ft  None   None
# ...    ...        ...     ...   ...    ...   ...   ...   ...   ...    ...
# 7014     l  markkanen  misses  2-pt  layup  from     6    ft  None   None
# 7015     c     sexton  misses  free  throw     1    of     2  None   None
# 7016     c     sexton  misses  free  throw     2    of     2  None   None
# 7017     k     george  misses  free  throw     1    of     2  None   None
# 7018     d       bane  misses  3-pt   jump  shot  from    23    ft   None
#
#      word11 word12 word13
# 0      None   None   None
# 1      None   None   None
# 2      None   None   None
# 3      None   None   None
# 4      None   None   None
# ...     ...    ...    ...
# 7014   None   None   None
# 7015   None   None   None
# 7016   None   None   None
# 7017   None   None   None
# 7018   None   None   None
#
# [7019 rows x 13 columns]

# %%
fig, axs = plt.subplots(nrows=math.ceil(len(columns_misses_list)/2), ncols=2, figsize=(10, 30))

# Loop para criar os gráficos
for n, col in enumerate(columns_misses_list):
    
    # Converter o índice 'n' em índices de linha e coluna
    row = n // 2
    col_idx = n % 2
    
    top5_words = misses_df[col].value_counts(normalize=True)[0:10]
    sns.barplot(x=top5_words.index, y=top5_words.values, ax=axs[row, col_idx])

# %%
misses_df[misses_df['word3'] == "silva"]
# Out:
#      word1 word2  word3   word4 word5 word6 word7 word8 word9 word10 word11  \
# 6476     t    da  silva  misses  3-pt  jump  shot  from    23     ft   None
#
#      word12 word13
# 6476   None   None

# %% [markdown]
# ### Palavras a serem adicionadas

# %%
# Colunas necessárias 
pbp_tab_data['BLK'] = []
pbp_tab_data['BLK_by'] = []
pbp_tab_data['BLK_to'] = []

pbp_tab_data
# Out:
# {'key': [],
#  'quarter': [],
#  'time': [],
#  'team': [],
#  'player': [],
#  'PTS': [],
#  '2PA': [],
#  '2PM': [],
#  '3PA': [],
#  '3PM': [],
#  'FTA': [],
#  'FTM': [],
#  'DUNK': [],
#  'LAYUP': [],
#  'HOOK': [],
#  'JUMP': [],
#  'shoot_dist': [],
#  'AST': [],
#  'AST_by': [],
#  'AST_to': [],
#  'technical': [],
#  'flagrant': [],
#  'clear_path': [],
#  'BLK': [],
#  'BLK_by': [],
#  'BLK_to': []}

# %% [markdown]
# ## Rebotes

# %%
rebound_list = wanted_word_list(plays_list, 'rebound')
max_words_rebound_list = find_max_words(rebound_list)
columns_rebound_list = columns_def(max_words_rebound_list)

# %%
rebound_df = pd.DataFrame(rebound_list, columns=columns_rebound_list)
rebound_df
# Out:
#           word1    word2 word3 word4     word5
# 0     defensive  rebound    by     j    giddey
# 1     offensive  rebound    by     n   vučević
# 2     defensive  rebound    by     p  banchero
# 3     defensive  rebound    by     p  banchero
# 4     defensive  rebound    by     p  banchero
# ...         ...      ...   ...   ...       ...
# 7014  offensive  rebound    by     w   kessler
# 7015  offensive  rebound    by  team      None
# 7016  defensive  rebound    by     s    aldama
# 7017  offensive  rebound    by  team      None
# 7018  offensive  rebound    by     s    aldama
#
# [7019 rows x 5 columns]

# %%
fig, axs = plt.subplots(nrows=math.ceil(len(columns_rebound_list)/2), ncols=2, figsize=(10, 30))

# Loop para criar os gráficos
for n, col in enumerate(columns_rebound_list):
    
    # Converter o índice 'n' em índices de linha e coluna
    row = n // 2
    col_idx = n % 2
    
    top5_words = rebound_df[col].value_counts(normalize=True)[0:10]
    sns.barplot(x=top5_words.index, y=top5_words.values, ax=axs[row, col_idx])

# %% [markdown]
# ### Palavras a serem adicionadas

# %%
# Colunas necessárias 
pbp_tab_data['ORB'] = []
pbp_tab_data['DRB'] = []

pbp_tab_data
# Out:
# {'key': [],
#  'quarter': [],
#  'time': [],
#  'team': [],
#  'player': [],
#  'PTS': [],
#  '2PA': [],
#  '2PM': [],
#  '3PA': [],
#  '3PM': [],
#  'FTA': [],
#  'FTM': [],
#  'DUNK': [],
#  'LAYUP': [],
#  'HOOK': [],
#  'JUMP': [],
#  'shoot_dist': [],
#  'AST': [],
#  'AST_by': [],
#  'AST_to': [],
#  'technical': [],
#  'flagrant': [],
#  'clear_path': [],
#  'BLK': [],
#  'BLK_by': [],
#  'BLK_to': [],
#  'ORB': [],
#  'DRB': []}

# %% [markdown]
# ## Turnover

# %%
tov_list = wanted_word_list(plays_list, 'turnover')
max_words_tov_list = find_max_words(tov_list)
columns_tov_list = columns_def(max_words_tov_list)

# %%
tov_df = pd.DataFrame(tov_list, columns=columns_tov_list)
tov_df
# Out:
#          word1 word2 word3      word4 word5 word6   word7 word8 word9  \
# 0     turnover    by     j      suggs   bad  pass   steal    by     z
# 1     turnover    by     z     lavine  lost  ball   steal    by     j
# 2     turnover    by     z     lavine   bad  pass   steal    by     k
# 3     turnover    by     j      suggs   bad  pass   steal    by     j
# 4     turnover    by     z     lavine   bad  pass   steal    by     j
# ...        ...   ...   ...        ...   ...   ...     ...   ...   ...
# 1982  turnover    by     j    collins  lost  ball   steal    by     s
# 1983  turnover    by     c   williams  lost  ball   steal    by     j
# 1984  turnover    by     s     pippen   bad  pass    None  None  None
# 1985  turnover    by     j     morant  lost  ball   steal    by     t
# 1986  turnover    by     l  markkanen   out    of  bounds  lost  ball
#
#              word10 word11
# 0            lavine   None
# 1             suggs   None
# 2     caldwell-pope   None
# 3          phillips   None
# 4             suggs   None
# ...             ...    ...
# 1982         pippen   None
# 1983         morant   None
# 1984           None   None
# 1985      hendricks   None
# 1986           None   None
#
# [1987 rows x 11 columns]

# %%
fig, axs = plt.subplots(nrows=math.ceil(len(columns_tov_list)), figsize=(10, 30))

# Loop para criar os gráficos
for n, col in enumerate(columns_tov_list):
    
    # Converter o índice 'n' em índices de linha e coluna
    row = n // 1
    
    top5_words = tov_df[col].value_counts(normalize=True)[0:15]
    sns.barplot(x=top5_words.index, y=top5_words.values, ax=axs[row])
    axs[row].set_title(col)

# %%
#tov_df[tov_df['word5'] == 'bad']

# %%
#tov_df[tov_df['word5'] == 'lost']

# %%
#tov_df[tov_df['word5'] == 'offensive']

# %%
#tov_df[tov_df['word5'] == 'traveling']

# %%
#tov_df[tov_df['word5'] == 'back']

# %%
#tov_df[tov_df['word5'] == 'step']

# %%
#tov_df[tov_df['word5'] == 'dbl']

# %%
#tov_df[tov_df['word5'] == 'off']

# %%
#tov_df[tov_df['word5'] == 'discontinued']

# %%
#tov_df[tov_df['word5'] == 'palming']

# %%
#tov_df[tov_df['word5'] == '3']

# %%
#tov_df[tov_df['word5'] == 'inbound']

# %%
#tov_df[tov_df['word5'] == 'lane']

# %%
#tov_df[tov_df['word7'] == 'bounds']

# %%
#tov_df[tov_df['word8'] == 'bounds']

# %%
#tov_df[tov_df['word8'] == 'lost']

# %% [markdown]
# ### Palavras adicionadas

# %%
pbp_tab_data['TOV'] = []
pbp_tab_data['bad_pass'] = []
pbp_tab_data['lost_ball'] = []
pbp_tab_data['PF'] = []
pbp_tab_data['offensive_foul'] = []
pbp_tab_data['offensive_draw'] = []
pbp_tab_data['travelling'] = []
pbp_tab_data['back_court'] = []
pbp_tab_data['dbl_dribbling'] = []
pbp_tab_data['palming'] = []
pbp_tab_data['off_goaltending'] = []
pbp_tab_data['disc_dribbling'] = []
pbp_tab_data['out_of_bounds'] = []
pbp_tab_data['step_out_of_bounds'] = []
pbp_tab_data['off_3_sec'] = []
pbp_tab_data['inbound'] = []
pbp_tab_data['lane_violation'] = []
pbp_tab_data['STL'] = []
pbp_tab_data['STL_by'] = []
pbp_tab_data['STL_to'] = []

pbp_tab_data
# Out:
# {'key': [],
#  'quarter': [],
#  'time': [],
#  'team': [],
#  'player': [],
#  'PTS': [],
#  '2PA': [],
#  '2PM': [],
#  '3PA': [],
#  '3PM': [],
#  'FTA': [],
#  'FTM': [],
#  'DUNK': [],
#  'LAYUP': [],
#  'HOOK': [],
#  'JUMP': [],
#  'shoot_dist': [],
#  'AST': [],
#  'AST_by': [],
#  'AST_to': [],
#  'technical': [],
#  'flagrant': [],
#  'clear_path': [],
#  'BLK': [],
#  'BLK_by': [],
#  'BLK_to': [],
#  'ORB': [],
#  'DRB': [],
#  'TOV': [],
#  'bad_pass': [],
#  'lost_ball': [],
#  'PF': [],
#  'offensive_foul': [],
#  'offensive_draw': [],
#  'travelling': [],
#  'back_court': [],
#  'dbl_dribbling': [],
#  'palming': [],
#  'off_goaltending': [],
#  'disc_dribbling': [],
#  'out_of_bounds': [],
#  'step_out_of_bounds': [],
#  'off_3_sec': [],
#  'inbound': [],
#  'lane_violation': [],
#  'STL': [],
#  'STL_by': [],
#  'STL_to': []}

# %% [markdown]
# ## Foul

# %%
foul_list = wanted_word_list(plays_list, 'foul')
max_words_foul_list = find_max_words(foul_list)
columns_foul_list = columns_def(max_words_foul_list)

# %%
foul_df = pd.DataFrame(foul_list, columns=columns_foul_list)
foul_df
# Out:
#          word1 word2 word3 word4     word5   word6  word7 word8     word9  \
# 0     shooting  foul    by     j     suggs   drawn     by     p  williams
# 1     shooting  foul    by     p  banchero   drawn     by     z    lavine
# 2     personal  foul    by     f    wagner   drawn     by     z    lavine
# 3     shooting  foul    by     j    giddey   drawn     by     p  banchero
# 4     shooting  foul    by     a    sanogo   drawn     by     m    wagner
# ...        ...   ...   ...   ...       ...     ...    ...   ...       ...
# 3107  personal  foul    by     j    morant   drawn     by     c    sexton
# 3108  personal  foul    by     m     smart   drawn     by     c    sexton
# 3109  shooting  foul    by     j      huff   drawn     by     k    george
# 3110  shooting  foul    by     m     smart   drawn     by     k    george
# 3111  personal  take  foul    by         k  george  drawn    by         d
#
#      word10 word11
# 0      None   None
# 1      None   None
# 2      None   None
# 3      None   None
# 4      None   None
# ...     ...    ...
# 3107   None   None
# 3108   None   None
# 3109   None   None
# 3110   None   None
# 3111   bane   None
#
# [3112 rows x 11 columns]

# %%
fig, axs = plt.subplots(nrows=math.ceil(len(columns_foul_list)), figsize=(10, 30))

# Loop para criar os gráficos
for n, col in enumerate(columns_foul_list):
    
    # Converter o índice 'n' em índices de linha e coluna
    row = n // 1
    
    top5_words = foul_df[col].value_counts(normalize=True)[0:15]
    sns.barplot(x=top5_words.index, y=top5_words.values, ax=axs[row])
    axs[row].set_title(col)
    
plt.tight_layout()  # Para melhorar a disposição dos gráficos
plt.show()

# %%
#foul_df[foul_df['word1'] == 'shooting']

# %%
#foul_df[foul_df['word1'] == 'personal']

# %%
#foul_df[foul_df['word1'] == 'offensive']

# %%
#foul_df[foul_df['word1'] == 'loose']

# %%
#foul_df[foul_df['word1'] == 'technical']

# %%
#foul_df[foul_df['word1'] == 'flagrant']

# %%
#foul_df[foul_df['word1'] == 'def']

# %%
#foul_df[foul_df['word1'] == 'away']

# %%
#foul_df[foul_df['word1'] == 'clear']

# %% [markdown]
# ### Palavras adicionadas

# %%
pbp_tab_data['shooting_foul'] = []
pbp_tab_data['shooting_foul_draw'] = []
pbp_tab_data['personal_foul'] = []
pbp_tab_data['personal_foul_draw'] = []
pbp_tab_data['personal_take_foul'] = []
pbp_tab_data['personal_take_foul_draw'] = []
pbp_tab_data['loose_ball_foul'] = []
pbp_tab_data['loose_ball_foul_draw'] = []
pbp_tab_data['technical_foul'] = []
pbp_tab_data['flagrant_1_foul'] = []
pbp_tab_data['flagrant_1_foul_draw'] = []
pbp_tab_data['flagrant_2_foul'] = []
pbp_tab_data['flagrant_2_foul_draw'] = []
pbp_tab_data['def_3_sec'] = []
pbp_tab_data['away_from_play_foul'] = []
pbp_tab_data['away_from_play_foul_draw'] = []
pbp_tab_data['clear_path_foul'] = []

pbp_tab_data
# Out:
# {'key': [],
#  'quarter': [],
#  'time': [],
#  'team': [],
#  'player': [],
#  'PTS': [],
#  '2PA': [],
#  '2PM': [],
#  '3PA': [],
#  '3PM': [],
#  'FTA': [],
#  'FTM': [],
#  'DUNK': [],
#  'LAYUP': [],
#  'HOOK': [],
#  'JUMP': [],
#  'shoot_dist': [],
#  'AST': [],
#  'AST_by': [],
#  'AST_to': [],
#  'technical': [],
#  'flagrant': [],
#  'clear_path': [],
#  'BLK': [],
#  'BLK_by': [],
#  'BLK_to': [],
#  'ORB': [],
#  'DRB': [],
#  'TOV': [],
#  'bad_pass': [],
#  'lost_ball': [],
#  'PF': [],
#  'offensive_foul': [],
#  'offensive_draw': [],
#  'travelling': [],
#  'back_court': [],
#  'dbl_dribbling': [],
#  'palming': [],
#  'off_goaltending': [],
#  'disc_dribbling': [],
#  'out_of_bounds': [],
#  'step_out_of_bounds': [],
#  'off_3_sec': [],
#  'inbound': [],
#  'lane_violation': [],
#  'STL': [],
#  'STL_by': [],
#  'STL_to': [],
#  'shooting_foul': [],
#  'shooting_foul_draw': [],
#  'personal_foul': [],
#  'personal_foul_draw': [],
#  'personal_take_foul': [],
#  'personal_take_foul_draw': [],
#  'loose_ball_foul': [],
#  'loose_ball_foul_draw': [],
#  'technical_foul': [],
#  'flagrant_1_foul': [],
#  'flagrant_1_foul_draw': [],
#  'flagrant_2_foul': [],
#  'flagrant_2_foul_draw': [],
#  'def_3_sec': [],
#  'away_from_play_foul': [],
#  'away_from_play_foul_draw': [],
#  'clear_path_foul': []}

# %% [markdown]
# # Funçoes para a conversão de texto para dado tabular

# %% [markdown]
# ### Funções de apoio

# %%
# Funções para completar as colunas com zeros
def complete_row(stats_dict, rows):
    
    for i in list(stats_dict.keys())[5:]:
        if i not in rows:
            stats_dict[i].append(0)

# %%
# Cópia de dicionário para testar as funções
teste_dict = {}
for k in pbp_tab_data.keys():
    teste_dict[k] = []

# %%
df_teste = merge_df.copy()
df_teste
# Out:
#                                     key quarter     time    score  \
# 0      /boxscores/pbp/202410300CHI.html      Q1  11:44.0      3-0
# 1      /boxscores/pbp/202410300CHI.html      Q1  11:27.0      3-2
# 2      /boxscores/pbp/202410300CHI.html      Q1  11:15.0      3-2
# 3      /boxscores/pbp/202410300CHI.html      Q1  11:12.0      3-2
# 4      /boxscores/pbp/202410300CHI.html      Q1  11:01.0      3-2
# ...                                 ...     ...      ...      ...
# 31152  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  125-121
# 31153  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31154  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31155  /boxscores/pbp/202410230UTA.html      Q4   0:06.0  126-121
# 31156  /boxscores/pbp/202410230UTA.html      Q4   0:04.0  126-124
#
#                team_play                                               play  \
# 0          Orlando Magic  K. Caldwell-Pope makes 3-pt jump shot from 26 ...
# 1          Chicago Bulls          J. Giddey makes 2-pt jump shot from 20 ft
# 2          Orlando Magic        P. Banchero misses 2-pt jump shot from 6 ft
# 3          Chicago Bulls                     Defensive rebound by J. Giddey
# 4          Chicago Bulls            P. Williams misses 2-pt layup from 2 ft
# ...                  ...                                                ...
# 31152  Memphis Grizzlies                    D. Bane makes free throw 1 of 2
# 31153  Memphis Grizzlies                    D. Bane makes free throw 2 of 2
# 31154          Utah Jazz                                  Utah full timeout
# 31155          Utah Jazz           C. Sexton enters the game for W. Kessler
# 31156          Utah Jazz  L. Markkanen makes 3-pt jump shot from 27 ft (...
#
#                away_team      home_team  \
# 0          Orlando Magic  Chicago Bulls
# 1          Orlando Magic  Chicago Bulls
# 2          Orlando Magic  Chicago Bulls
# 3          Orlando Magic  Chicago Bulls
# 4          Orlando Magic  Chicago Bulls
# ...                  ...            ...
# 31152  Memphis Grizzlies      Utah Jazz
# 31153  Memphis Grizzlies      Utah Jazz
# 31154  Memphis Grizzlies      Utah Jazz
# 31155  Memphis Grizzlies      Utah Jazz
# 31156  Memphis Grizzlies      Utah Jazz
#
#                                               clean_play
# 0      [k, caldwell-pope, makes, 3-pt, jump, shot, fr...
# 1      [j, giddey, makes, 2-pt, jump, shot, from, 20,...
# 2      [p, banchero, misses, 2-pt, jump, shot, from, ...
# 3                    [defensive, rebound, by, j, giddey]
# 4        [p, williams, misses, 2-pt, layup, from, 2, ft]
# ...                                                  ...
# 31152            [d, bane, makes, free, throw, 1, of, 2]
# 31153            [d, bane, makes, free, throw, 2, of, 2]
# 31154                              [utah, full, timeout]
# 31155    [c, sexton, enters, the, game, for, w, kessler]
# 31156  [l, markkanen, makes, 3-pt, jump, shot, from, ...
#
# [31157 rows x 9 columns]

# %% [markdown]
# ## Funções de arremessos feitos

# %% [markdown]
# ### Assistências

# %%
def AST(key, quarter, time, team_play, play, _dict, rows):
    
    _dict['AST_by'].append(' '.join([play[-2], play[-1]])) 
    rows.append('AST_by')
    complete_row(_dict, rows)

    #Completando as stats do jogador que deu a assisteência
    _dict['key'].append(key)
    _dict['quarter'].append(quarter)
    _dict['time'].append(time)
    _dict['team'].append(team_play)    
    _dict['player'].append(' '.join([play[-2], play[-1]]))
    _dict['AST'].append(1)
    _dict['AST_to'].append(' '.join([play[0], play[1]]))

    rows = ['AST', 'AST_to']
    complete_row(_dict, rows)

# %% [markdown]
# ### Arremesso de 3 pontos

# %%
#função para pontuar arremessos de 3 pontos com ou sem assistência
def _3PM(key, quarter, time, team_play, play, _dict):
    
    #inputs iniciais
    _dict['key'].append(key)
    _dict['quarter'].append(quarter)
    _dict['time'].append(time)
    _dict['team'].append(team_play)    
    _dict['player'].append(' '.join([play[0], play[1]]))
    _dict['PTS'].append(3)
    _dict['3PA'].append(1)
    _dict['3PM'].append(1)
    _dict['JUMP'].append(1)
    _dict['shoot_dist'].append(play[7])
    
    rows = ['PTS','3PA','3PM','JUMP','shoot_dist' ]
    
    #checando se tem assistência
    if 'assist' in play:
         AST(key, quarter, time, team_play, play, _dict, rows)      
    else:
        complete_row(_dict, rows)

# %% [markdown]
# ### Aremessos de 2 pontos

# %%
#Função para tabular jumpshots
def jump(_dict, play, rows):
    _dict['JUMP'].append(1)
    rows.append('JUMP')

    _dict['shoot_dist'].append(play[7])
    rows.append('shoot_dist')

# %%
#Função para tabular hookshots
def hook(_dict, play, rows):
    _dict['HOOK'].append(1)
    rows.append('HOOK')

    _dict['shoot_dist'].append(play[7])
    rows.append('shoot_dist')

# %%
#Função para tabular dunks
def dunk(_dict, play, rows):
    _dict['DUNK'].append(1)
    rows.append('DUNK')

    _dict['shoot_dist'].append(play[6])
    rows.append('shoot_dist')

# %%
#Função para tabular layups
def layup(_dict, play, rows):
    _dict['LAYUP'].append(1)
    rows.append('LAYUP')

    _dict['shoot_dist'].append(play[6])
    rows.append('shoot_dist')

# %%
def _2PM(key, quarter, time, team_play, play, _dict):
    
    #inputs iniciais
    _dict['key'].append(key)
    _dict['quarter'].append(quarter)
    _dict['time'].append(time)
    _dict['team'].append(team_play)    
    _dict['player'].append(' '.join([play[0], play[1]]))
    _dict['PTS'].append(2)
    _dict['2PA'].append(1)
    _dict['2PM'].append(1)

    #rows com inputs
    rows = ['PTS','2PA','2PM']
    
    #checando tipo de arremesso
    if play[4] == 'jump':
        jump(_dict, play, rows)
   
    if play[4] == 'hook':
        hook(_dict, play, rows)   
    
    if play[4] == 'dunk':
        dunk(_dict, play, rows)

    if play[4] == 'layup':
        layup(_dict, play, rows)

        
    #checando se tem assistência
    if 'assist' in play:
         AST(key, quarter, time, team_play, play, _dict, rows)      
    else:
        complete_row(_dict, rows)

# %% [markdown]
# ### FT

# %%
def FT(key, quarter, time, team_play, play, _dict):
    
    #inputs iniciais
    _dict['key'].append(key)
    _dict['quarter'].append(quarter)
    _dict['time'].append(time)
    _dict['team'].append(team_play)    
    _dict['player'].append(' '.join([play[0], play[1]]))
    _dict['PTS'].append(1)
    _dict['FTA'].append(1)
    _dict['FTM'].append(1)
    
    #rows com inputs
    rows = ['PTS','FTA','FTM']    
    
    if play[3] == 'technical':
        _dict['technical'].append(1)
        rows.append('technical')
        
    if play[3] == 'flagrant':
        _dict['flagrant'].append(1)
        rows.append('flagrant')
    
    if play[3] == 'clear':
        _dict['clear_path'].append(1)
        rows.append('clear_path')
        
    complete_row(_dict, rows)

# %% [markdown]
# ## Função de arremessos feitos

# %%
def makes(key, quarter, time, team_play, play, _dict):
    
    if play[3] == '2-pt':
        _2PM(key, quarter, time, team_play, play, _dict)
    elif play[3] == '3-pt':
        _3PM(key, quarter, time, team_play, play, _dict) 
    else:
        FT(key, quarter, time, team_play, play, _dict)

# %%
# Out:
# Warning:makes is <function makes at 0x32c5fa3b0>
# Proper storage of interactively declared classes (or instances
# of those classes) is not possible! Only instances
# of classes in real modules on file system can be %store'd.

# %% [markdown]
# ### Testes

# %%
makes_df[makes_df['word3'] == "makes"]['word4'].value_counts()

# %%
df_teste[df_teste['play'].str.contains('makes clear')]

# %%
i = 1
key = df_teste.iloc[i,:]['key']
quarter = df_teste.iloc[i,:]['quarter']
time = df_teste.iloc[i,:]['time']
team_play = df_teste.iloc[i,:]['team_play']
away_team = df_teste.iloc[i,:]['away_team']
home_team = df_teste.iloc[i,:]['home_team']
clean_play = df_teste.iloc[i,:]['clean_play']
print(clean_play)

# %%
makes(key, quarter, time, team_play, clean_play, teste_dict)
teste_dict

# %%
teste_dict = {}
for k in pbp_tab_data.keys():
    teste_dict[k] = []

# %%
! git add .

! git commit -m "31/10/2024"

! git push
